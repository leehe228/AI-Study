# %% [markdown]
# # Plant Pathology 2020 - FGVC7
# https://www.kaggle.com/c/plant-pathology-2020-fgvc7

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

op = os.path.join

# %%
import torch

# %% [markdown]
# ### CUDA GPU Device Checking

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ### Path

# %%
path = "/home/dmsai2/Desktop/AI_Hackathon/data/"
train_csv = op(path, "train.csv")
test_csv = op(path, "test.csv")
train_path = op(path, "images", "Train")
test_path = op(path, "images", "Test")

# %%
print("train:", len(os.listdir(train_path)))
print("test:", len(os.listdir(test_path)))
num_train_data = len(os.listdir(train_path))
# Out:
# train: 1821
# test: 1822

# %% [markdown]
# ### Convert `train.csv` to `train2.csv`

# %%
# import csv

# f = open(op(path, 'train.csv'), 'r')
# f2 = open(op(path, 'train2.csv'), 'w', newline='')
# reader = csv.reader(f)
# writer = csv.writer(f2)

# for line in reader:
#     label = line[0]
#     onehot = line[1:]
#     writer.writerow([label+'.jpg', np.argmax(onehot)])
    
# f.close()
# f2.close()

# %%
from torch.utils.data import Dataset
from torchvision.io import read_image

# %% [markdown]
# ### Resizing Image Test

# %%
img_path = op(train_path, 'Train_0.jpg')
img = cv2.imread(img_path)

# %%
# plt.imshow(img, cmap='gray')

# %%
img = cv2.resize(img, (224, 224))

# %%
# plt.imshow(img, cmap='gray')

# %%
import torchvision.transforms as transforms

# %%
tf = transforms.ToTensor()
tensor_img = tf(img)

# %%
tensor_img.shape
# Out:
# torch.Size([3, 224, 224])

# %% [markdown]
# ### `read_image_resize()`

# %%
tf = transforms.ToTensor()

def read_image_resize(img_path, dsize=(224, 224)):
    assert type(dsize) == tuple and len(dsize) == 2
    img = cv2.imread(img_path)
    img = cv2.resize(img, dsize)
    tensor_img = tf(img)
    return tensor_img

# %% [markdown]
# ### centercrop by lawjwpark

# %%
import albumentations as A

# %%
aug_cc = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.Rotate(limit=45, always_apply=True),
    
    A.ShiftScaleRotate(scale_limit=(0.7, 0.9), rotate_limit=30, p=1),
    A.RandomBrightnessContrast(brightness_limit=(-0.2, 0.2), contrast_limit=(-0.2, 0.2), p=0.5),
    A.CenterCrop(height=1365, width=1365, p=1.0),
    A.Resize(height=224, width=224, p=1)
])

# %%
img_path = op(train_path, 'Train_0.jpg')
img = cv2.imread(img_path)

# %%
img = aug_cc(image=img)['image']

# %%
tensor_img = tf(img)

# %%
tensor_img.shape
# Out:
# torch.Size([3, 224, 224])

# %%
def centercrop(img_path, dsize=(224, 224)):
    img = cv2.imread(img_path)
    img = aug_cc(image=img)['image']
    tensor_img = tf(img)
    return tensor_img

# %% [markdown]
# ### PyTorch Customized `Datasets` Class
# - https://pytorch.org/tutorials/beginner/basics/data_tutorial.html

# %% [markdown]
# one-hot encoding이 반드시 필요할까?
# - https://study-grow.tistory.com/entry/pytorch-one-hot-encoding%EC%9D%B4-%EB%B0%98%EB%93%9C%EC%8B%9C-%ED%95%84%EC%9A%94%ED%95%A0%EA%B9%8C

# %%
import torch.nn.functional as F

# %%
class PlantPathologyDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None, target_transform=None, header=None):
        self.img_labels = pd.read_csv(annotations_file)
        self.img_dir = img_dir
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)
    
    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        # image = read_image(img_path)
        # read image with resizing to (224, 224)
        
        # image = read_image_resize(img_path + '.jpg')
        image = centercrop(img_path + '.jpg')
        
        # augmentation here
        # image = augmentation(image)
        
        # label = [self.img_labels.iloc[idx, 1], 
        #          self.img_labels.iloc[idx, 2],
        #          self.img_labels.iloc[idx, 3],
        #          self.img_labels.iloc[idx, 4]]
        # label = F.one_hot(label)
        label = np.argmax(self.img_labels.iloc[idx, 1:].values)

        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %% [markdown]
# ### Load Training Data

# %%
training_data = PlantPathologyDataset(train_csv, train_path)
test_data = PlantPathologyDataset(test_csv, test_path)

# %% [markdown]
# ### Show Example Images

# %%
def show_images(data, is_test=False):
    f, ax = plt.subplots(5, 5, figsize=(15, 10))
    
    for i in range(25):
        img_dir = data.img_labels.iloc[i, 0]
        img_data = cv2.imread(op(train_path, img_dir + '.jpg'))
        label = np.argmax(data.img_labels.iloc[0, 1:].values)
        
        if label  == 0:  str_label = 'healthy'
        elif label == 1:  str_label = 'multiple_diseases'
        elif label == 2: str_label = 'rust'
        else: str_label = 'scab'
        if(is_test): str_label="None"
        
        ax[i//5, i%5].imshow(img_data)
        ax[i//5, i%5].axis('off')
        ax[i//5, i%5].set_title("Label: {}".format(str_label))
        
    plt.show()

# %%
# show_images(training_data)

# %% [markdown]
# ### DataLoader

# %%
from torch.utils.data import DataLoader

# %%
BATCH_SIZE = 32

# %%
train_dataloader = DataLoader(training_data, batch_size=BATCH_SIZE, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=BATCH_SIZE)

# %%
X_train, y_train = next(iter(train_dataloader))
print(f"Feature batch shape: {X_train.size()}")
print(f"Labels batch shape: {y_train.size()}")
# Out:
# Feature batch shape: torch.Size([32, 3, 224, 224])
# Labels batch shape: torch.Size([32])

# %% [markdown]
# ### Convert to One-hot encoding

# %%
y_train
# Out:
# tensor([2, 3, 3, 0, 2, 2, 0, 3, 0, 3, 3, 2, 3, 0, 0, 0, 3, 3, 2, 0, 0, 0, 2, 2,
#         2, 0, 0, 2, 0, 0, 3, 3])

# %%
# y_train = F.one_hot(y_train, num_classes=4).double()
# y_train

# %% [markdown]
# ### Train Test Data Split

# %%
from sklearn.model_selection import train_test_split

# %%
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=101)

# %% [markdown]
# ### ResNet50

# %%
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, activation=True, **kwargs):
        super(ConvBlock, self).__init__()
        self.relu = nn.ReLU()
        self.conv = nn.Conv2d(in_channels, out_channels, **kwargs)
        self.batchnorm = nn.BatchNorm2d(out_channels)
        self.activation = activation

    def forward(self, x):
        if not self.activation:
            return self.batchnorm(self.conv(x))
        else:
            return self.relu(self.batchnorm(self.conv(x)))

# %%
class ResBlock(nn.Module):
    def __init__(self, in_channels, red_channels, out_channels, is_plain=False):
        super(ResBlock, self).__init__()
        self.relu = nn.ReLU()
        self.is_plain = is_plain
        
        if in_channels == 64:
            self.convseq = nn.Sequential(
                ConvBlock(in_channels, red_channels, kernel_size=1, padding=0),
                ConvBlock(red_channels, red_channels, kernel_size=3, padding=1),
                ConvBlock(red_channels, out_channels, activation=False, kernel_size=1, padding=0)
            )
            self.iden = nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1)
        elif in_channels == out_channels:
            self.convseq = nn.Sequential(
                ConvBlock(in_channels, red_channels, kernel_size=1, padding=0),
                ConvBlock(red_channels, red_channels, kernel_size=3, padding=1),
                ConvBlock(red_channels, out_channels, activation=False, kernel_size=1, padding=0)
            )
            self.iden = nn.Identity()
        else:
            self.convseq = nn.Sequential(
                ConvBlock(in_channels, red_channels, kernel_size=1, padding=0, stride=2),
                ConvBlock(red_channels, red_channels, kernel_size=3, padding=1),
                ConvBlock(red_channels, out_channels, activation=False, kernel_size=1, padding=0)
            )
            self.iden = nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=2)
            
    def forward(self, x):
        y = self.convseq(x)
        if self.is_plain:
            x = y
        else:
            x = y + self.iden(x)
        x = self.relu(x)
        return x

# %% [markdown]
# **PyTorch Global Average Pooling**
# - https://gaussian37.github.io/dl-concept-global_average_pooling/

# %%
class ResNet(nn.Module):
    def __init__(self, in_channels=3, num_classes=1000, is_plain=False):
        self.num_classes = num_classes
        super(ResNet, self).__init__()
        self.conv1 = ConvBlock(in_channels=in_channels, out_channels=64, kernel_size=7, stride=2, padding=3)
        self.maxpool1 = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        
        self.conv2_x = nn.Sequential(
            ResBlock(64, 64, 256, is_plain),
            ResBlock(256, 64, 256, is_plain),
            ResBlock(256, 64, 256, is_plain)
        )
        
        self.conv3_x = nn.Sequential(
            ResBlock(256, 128, 512, is_plain),
            ResBlock(512, 128, 512, is_plain),
            ResBlock(512, 128, 512, is_plain),
            ResBlock(512, 128, 512, is_plain)
        )
        
        self.conv4_x = nn.Sequential(
            ResBlock(512, 256, 1024, is_plain),
            ResBlock(1024, 256, 1024, is_plain),
            ResBlock(1024, 256, 1024, is_plain),
            ResBlock(1024, 256, 1024, is_plain),
            ResBlock(1024, 256, 1024, is_plain),
            ResBlock(1024, 256, 1024, is_plain)
        )
        
        self.conv5_x = nn.Sequential(
            ResBlock(1024, 512, 2048, is_plain),
            ResBlock(2048, 512, 2048, is_plain),
            ResBlock(2048, 512, 2048, is_plain),
        )
        
        self.avgpool = nn.AvgPool2d(kernel_size=7, stride=1)
        self.fc = nn.Linear(2048, num_classes)
        self.gapool = nn.AdaptiveAvgPool2d((1, 1))
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.maxpool1(x)
        x = self.conv2_x(x)
        x = self.conv3_x(x)
        x = self.conv4_x(x)
        x = self.conv5_x(x)
        x = self.avgpool(x)
        x = x.reshape(x.shape[0], -1)
        # x = self.gapool(x)
        x = self.fc(x)
        return x

# %% [markdown]
# ### Build ResNet50
# - https://pseudo-lab.github.io/pytorch-guide/docs/ch03-1.html
# - https://velog.io/@gibonki77/ResNetwithPyTorch

# %%
from torchsummary import summary as summary_

# %%
def build_resnet(input_shape=(3, 224, 224), is_50=True, is_plain=False, **kwargs):
    x = torch.randn(2, *input_shape).to(device)
    
    if is_50:
        model = ResNet(is_plain=is_plain, **kwargs).to(device)
        assert model(x).shape == torch.Size([2, model.num_classes])
        
        if is_plain == False:
            print("ResNet50 Created")
        if is_plain == True:
            print("PlainNet50 Created")
            
        print(summary_(model, (3, 224, 224), batch_size=2))
        return model
    
    else:
        model = ResNet_34(is_plain=is_plain).to(device)
        assert model(x).shape == torch.Size([2, model.num_classes])
        
        if is_plain == False:
            print("ResNet34 Created")
        if is_plain == True:
            print("PlainNet34 Created")

        print(summary_(model, (3, 224, 224), batch_size=2))
        return model

# %%
res50 = build_resnet(is_plain=True, num_classes=4)
# Out:
# PlainNet50 Created
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [2, 64, 112, 112]           9,472
#        BatchNorm2d-2          [2, 64, 112, 112]             128
#               ReLU-3          [2, 64, 112, 112]               0
#          ConvBlock-4          [2, 64, 112, 112]               0
#          MaxPool2d-5            [2, 64, 56, 56]               0
#             Conv2d-6            [2, 64, 56, 56]           4,160
#        BatchNorm2d-7            [2, 64, 56, 56]             128
#               ReLU-8            [2, 64, 56, 56]               0
#          ConvBlock-9            [2, 64, 56, 56]               0
#            Conv2d-10            [2, 64, 56, 56]          36,928
#       BatchNorm2d-11            [2, 64, 56, 56]             128
#              ReLU-12            [2, 64, 56, 56]               0
#         ConvBlock-13            [2, 64, 56, 56]               0
#            Conv2d-14           [2, 256, 56, 56]          16,640
#       BatchNorm2d-15           [2, 256, 56, 56]             512
#         ConvBlock-16           [2, 256, 56, 56]               0
#              ReLU-17           [2, 256, 56, 56]               0
#          ResBlock-18           [2, 256, 56, 56]               0
#            Conv2d-19            [2, 64, 56, 56]          16,448
#       BatchNorm2d-20            [2, 64, 56, 56]             128
#              ReLU-21            [2, 64, 56, 56]               0
#         ConvBlock-22            [2, 64, 56, 56]               0
#            Conv2d-23            [2, 64, 56, 56]          36,928
#       BatchNorm2d-24            [2, 64, 56, 56]             128
#              ReLU-25            [2, 64, 56, 56]               0
#         ConvBlock-26            [2, 64, 56, 56]               0
#            Conv2d-27           [2, 256, 56, 56]          16,640
#       BatchNorm2d-28           [2, 256, 56, 56]             512
#         ConvBlock-29           [2, 256, 56, 56]               0
#              ReLU-30           [2, 256, 56, 56]               0
#          ResBlock-31           [2, 256, 56, 56]               0
#            Conv2d-32            [2, 64, 56, 56]          16,448
#       BatchNorm2d-33            [2, 64, 56, 56]             128
#              ReLU-34            [2, 64, 56, 56]               0
#         ConvBlock-35            [2, 64, 56, 56]               0
#            Conv2d-36            [2, 64, 56, 56]          36,928
#       BatchNorm2d-37            [2, 64, 56, 56]             128
#              ReLU-38            [2, 64, 56, 56]               0
#         ConvBlock-39            [2, 64, 56, 56]               0
#            Conv2d-40           [2, 256, 56, 56]          16,640
#       BatchNorm2d-41           [2, 256, 56, 56]             512
#         ConvBlock-42           [2, 256, 56, 56]               0
#              ReLU-43           [2, 256, 56, 56]               0
#          ResBlock-44           [2, 256, 56, 56]               0
#            Conv2d-45           [2, 128, 28, 28]          32,896
#       BatchNorm2d-46           [2, 128, 28, 28]             256
#              ReLU-47           [2, 128, 28, 28]               0
#         ConvBlock-48           [2, 128, 28, 28]               0
#            Conv2d-49           [2, 128, 28, 28]         147,584
#       BatchNorm2d-50           [2, 128, 28, 28]             256
#              ReLU-51           [2, 128, 28, 28]               0
#         ConvBlock-52           [2, 128, 28, 28]               0
#            Conv2d-53           [2, 512, 28, 28]          66,048
#       BatchNorm2d-54           [2, 512, 28, 28]           1,024
#         ConvBlock-55           [2, 512, 28, 28]               0
#              ReLU-56           [2, 512, 28, 28]               0
#          ResBlock-57           [2, 512, 28, 28]               0
#            Conv2d-58           [2, 128, 28, 28]          65,664
#       BatchNorm2d-59           [2, 128, 28, 28]             256
#              ReLU-60           [2, 128, 28, 28]               0
#         ConvBlock-61           [2, 128, 28, 28]               0
#            Conv2d-62           [2, 128, 28, 28]         147,584
#       BatchNorm2d-63           [2, 128, 28, 28]             256
#              ReLU-64           [2, 128, 28, 28]               0
#         ConvBlock-65           [2, 128, 28, 28]               0
#            Conv2d-66           [2, 512, 28, 28]          66,048
#       BatchNorm2d-67           [2, 512, 28, 28]           1,024
#         ConvBlock-68           [2, 512, 28, 28]               0
#              ReLU-69           [2, 512, 28, 28]               0
#          ResBlock-70           [2, 512, 28, 28]               0
#            Conv2d-71           [2, 128, 28, 28]          65,664
#       BatchNorm2d-72           [2, 128, 28, 28]             256
#              ReLU-73           [2, 128, 28, 28]               0
#         ConvBlock-74           [2, 128, 28, 28]               0
#            Conv2d-75           [2, 128, 28, 28]         147,584
#       BatchNorm2d-76           [2, 128, 28, 28]             256
#              ReLU-77           [2, 128, 28, 28]               0
#         ConvBlock-78           [2, 128, 28, 28]               0
#            Conv2d-79           [2, 512, 28, 28]          66,048
#       BatchNorm2d-80           [2, 512, 28, 28]           1,024
#         ConvBlock-81           [2, 512, 28, 28]               0
#              ReLU-82           [2, 512, 28, 28]               0
#          ResBlock-83           [2, 512, 28, 28]               0
#            Conv2d-84           [2, 128, 28, 28]          65,664
#       BatchNorm2d-85           [2, 128, 28, 28]             256
#              ReLU-86           [2, 128, 28, 28]               0
#         ConvBlock-87           [2, 128, 28, 28]               0
#            Conv2d-88           [2, 128, 28, 28]         147,584
#       BatchNorm2d-89           [2, 128, 28, 28]             256
#              ReLU-90           [2, 128, 28, 28]               0
#         ConvBlock-91           [2, 128, 28, 28]               0
#            Conv2d-92           [2, 512, 28, 28]          66,048
#       BatchNorm2d-93           [2, 512, 28, 28]           1,024
#         ConvBlock-94           [2, 512, 28, 28]               0
#              ReLU-95           [2, 512, 28, 28]               0
#          ResBlock-96           [2, 512, 28, 28]               0
#            Conv2d-97           [2, 256, 14, 14]         131,328
#       BatchNorm2d-98           [2, 256, 14, 14]             512
#              ReLU-99           [2, 256, 14, 14]               0
#        ConvBlock-100           [2, 256, 14, 14]               0
#           Conv2d-101           [2, 256, 14, 14]         590,080
#      BatchNorm2d-102           [2, 256, 14, 14]             512
#             ReLU-103           [2, 256, 14, 14]               0
#        ConvBlock-104           [2, 256, 14, 14]               0
#           Conv2d-105          [2, 1024, 14, 14]         263,168
#      BatchNorm2d-106          [2, 1024, 14, 14]           2,048
#        ConvBlock-107          [2, 1024, 14, 14]               0
#             ReLU-108          [2, 1024, 14, 14]               0
#         ResBlock-109          [2, 1024, 14, 14]               0
#           Conv2d-110           [2, 256, 14, 14]         262,400
#      BatchNorm2d-111           [2, 256, 14, 14]             512
#             ReLU-112           [2, 256, 14, 14]               0
#        ConvBlock-113           [2, 256, 14, 14]               0
#           Conv2d-114           [2, 256, 14, 14]         590,080
#      BatchNorm2d-115           [2, 256, 14, 14]             512
#             ReLU-116           [2, 256, 14, 14]               0
#        ConvBlock-117           [2, 256, 14, 14]               0
#           Conv2d-118          [2, 1024, 14, 14]         263,168
#      BatchNorm2d-119          [2, 1024, 14, 14]           2,048
#        ConvBlock-120          [2, 1024, 14, 14]               0
#             ReLU-121          [2, 1024, 14, 14]               0
#         ResBlock-122          [2, 1024, 14, 14]               0
#           Conv2d-123           [2, 256, 14, 14]         262,400
#      BatchNorm2d-124           [2, 256, 14, 14]             512
#             ReLU-125           [2, 256, 14, 14]               0
#        ConvBlock-126           [2, 256, 14, 14]               0
#           Conv2d-127           [2, 256, 14, 14]         590,080
#      BatchNorm2d-128           [2, 256, 14, 14]             512
#             ReLU-129           [2, 256, 14, 14]               0
#        ConvBlock-130           [2, 256, 14, 14]               0
#           Conv2d-131          [2, 1024, 14, 14]         263,168
#      BatchNorm2d-132          [2, 1024, 14, 14]           2,048
#        ConvBlock-133          [2, 1024, 14, 14]               0
#             ReLU-134          [2, 1024, 14, 14]               0
#         ResBlock-135          [2, 1024, 14, 14]               0
#           Conv2d-136           [2, 256, 14, 14]         262,400
#      BatchNorm2d-137           [2, 256, 14, 14]             512
#             ReLU-138           [2, 256, 14, 14]               0
#        ConvBlock-139           [2, 256, 14, 14]               0
#           Conv2d-140           [2, 256, 14, 14]         590,080
#      BatchNorm2d-141           [2, 256, 14, 14]             512
#             ReLU-142           [2, 256, 14, 14]               0
#        ConvBlock-143           [2, 256, 14, 14]               0
#           Conv2d-144          [2, 1024, 14, 14]         263,168
#      BatchNorm2d-145          [2, 1024, 14, 14]           2,048
#        ConvBlock-146          [2, 1024, 14, 14]               0
#             ReLU-147          [2, 1024, 14, 14]               0
#         ResBlock-148          [2, 1024, 14, 14]               0
#           Conv2d-149           [2, 256, 14, 14]         262,400
#      BatchNorm2d-150           [2, 256, 14, 14]             512
#             ReLU-151           [2, 256, 14, 14]               0
#        ConvBlock-152           [2, 256, 14, 14]               0
#           Conv2d-153           [2, 256, 14, 14]         590,080
#      BatchNorm2d-154           [2, 256, 14, 14]             512
#             ReLU-155           [2, 256, 14, 14]               0
#        ConvBlock-156           [2, 256, 14, 14]               0
#           Conv2d-157          [2, 1024, 14, 14]         263,168
#      BatchNorm2d-158          [2, 1024, 14, 14]           2,048
#        ConvBlock-159          [2, 1024, 14, 14]               0
#             ReLU-160          [2, 1024, 14, 14]               0
#         ResBlock-161          [2, 1024, 14, 14]               0
#           Conv2d-162           [2, 256, 14, 14]         262,400
#      BatchNorm2d-163           [2, 256, 14, 14]             512
#             ReLU-164           [2, 256, 14, 14]               0
#        ConvBlock-165           [2, 256, 14, 14]               0
#           Conv2d-166           [2, 256, 14, 14]         590,080
#      BatchNorm2d-167           [2, 256, 14, 14]             512
#             ReLU-168           [2, 256, 14, 14]               0
#        ConvBlock-169           [2, 256, 14, 14]               0
#           Conv2d-170          [2, 1024, 14, 14]         263,168
#      BatchNorm2d-171          [2, 1024, 14, 14]           2,048
#        ConvBlock-172          [2, 1024, 14, 14]               0
#             ReLU-173          [2, 1024, 14, 14]               0
#         ResBlock-174          [2, 1024, 14, 14]               0
#           Conv2d-175             [2, 512, 7, 7]         524,800
#      BatchNorm2d-176             [2, 512, 7, 7]           1,024
#             ReLU-177             [2, 512, 7, 7]               0
#        ConvBlock-178             [2, 512, 7, 7]               0
#           Conv2d-179             [2, 512, 7, 7]       2,359,808
#      BatchNorm2d-180             [2, 512, 7, 7]           1,024
#             ReLU-181             [2, 512, 7, 7]               0
#        ConvBlock-182             [2, 512, 7, 7]               0
#           Conv2d-183            [2, 2048, 7, 7]       1,050,624
#      BatchNorm2d-184            [2, 2048, 7, 7]           4,096
#        ConvBlock-185            [2, 2048, 7, 7]               0
#             ReLU-186            [2, 2048, 7, 7]               0
#         ResBlock-187            [2, 2048, 7, 7]               0
#           Conv2d-188             [2, 512, 7, 7]       1,049,088
#      BatchNorm2d-189             [2, 512, 7, 7]           1,024
#             ReLU-190             [2, 512, 7, 7]               0
#        ConvBlock-191             [2, 512, 7, 7]               0
#           Conv2d-192             [2, 512, 7, 7]       2,359,808
#      BatchNorm2d-193             [2, 512, 7, 7]           1,024
#             ReLU-194             [2, 512, 7, 7]               0
#        ConvBlock-195             [2, 512, 7, 7]               0
#           Conv2d-196            [2, 2048, 7, 7]       1,050,624
#      BatchNorm2d-197            [2, 2048, 7, 7]           4,096
#        ConvBlock-198            [2, 2048, 7, 7]               0
#             ReLU-199            [2, 2048, 7, 7]               0
#         ResBlock-200            [2, 2048, 7, 7]               0
#           Conv2d-201             [2, 512, 7, 7]       1,049,088
#      BatchNorm2d-202             [2, 512, 7, 7]           1,024
#             ReLU-203             [2, 512, 7, 7]               0
#        ConvBlock-204             [2, 512, 7, 7]               0
#           Conv2d-205             [2, 512, 7, 7]       2,359,808
#      BatchNorm2d-206             [2, 512, 7, 7]           1,024
#             ReLU-207             [2, 512, 7, 7]               0
#        ConvBlock-208             [2, 512, 7, 7]               0
#           Conv2d-209            [2, 2048, 7, 7]       1,050,624
#      BatchNorm2d-210            [2, 2048, 7, 7]           4,096
#        ConvBlock-211            [2, 2048, 7, 7]               0
#             ReLU-212            [2, 2048, 7, 7]               0
#         ResBlock-213            [2, 2048, 7, 7]               0
#        AvgPool2d-214            [2, 2048, 1, 1]               0
#           Linear-215                     [2, 4]           8,196
# ================================================================
# Total params: 20,762,372
# Trainable params: 20,762,372
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.15
# Forward/backward pass size (MB): 641.63
# Params size (MB): 79.20
# Estimated Total Size (MB): 721.98
# ----------------------------------------------------------------
# None

# %% [markdown]
# ### Neptune

# %%
import neptune

# %%
run = neptune.init_run(
    project="leehe228/plant-pathology",
    api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI5MTRmYjRlNC0zODFlLTQ0ODItODY1MC1hZGQ0YTRhNDNlZjIifQ==",
)
# Out:
# /tmp/ipykernel_441958/590607257.py:1: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(
# https://app.neptune.ai/leehe228/plant-pathology/e/P001-13

# %% [markdown]
# ### Tensorboard

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()
# Out:
# 2023-05-11 04:22:39.410845: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-11 04:22:40.182454: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Hyperparameters

# %%
from torch import optim

# %%
params = {
    # lr 1e-3 ~ 1e-6
    "learning_rate": 1e-4,
    "batch_size": BATCH_SIZE,
    "input_size": 3 * 244 * 244,
    "num_epoch": 25,
    "n_classes": 4,
    "optimizer": 'Adam',
    "criterion": 'CrossEntropyLoss',
    "preproc_type": "centercrop",
    "device": str(device)
}
# add parameters
run["parameters"] = params

# %%
criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.Adam(res50.parameters(), lr=params['learning_rate'])

# %% [markdown]
# ### Training
# - https://pseudo-lab.github.io/pytorch-guide/docs/ch04-1.html
# - https://2021-01-06getstarted.tistory.com/m/49

# %%
def train(model, params, criterion, optimizer, writer):
    for epoch in range(0, params['num_epoch']):
        print(f"epoch {epoch + 1}.")
        for i, data in enumerate(train_dataloader, 0):
            # data, label 분리
            x_train, y_train = data
            labels = F.one_hot(y_train, num_classes=4).double()
            
            y_train = y_train.to(device)
            inputs = x_train.to(device)
            labels = labels.to(device)

            # 이전 batch에서 계산된 가중치 초기화
            optimizer.zero_grad()

            # forward + back propagation
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            # print(outputs, labels)
            train_loss = criterion(outputs, labels)
            # print("y_train", y_train)
            # print("preds", preds)
            # print("outputs", outputs)
            # print("labels", labels)
            train_acc = (torch.sum(preds == y_train)) / len(inputs) 

            # training batch loss and accuracy
            run["train/batch/loss"].append(train_loss)
            run["train/batch/acc"].append(train_acc)
            
            # tensorboard
            writer.add_scalar("loss/train", train_loss, epoch)
            writer.add_scalar("acc/train", train_acc, epoch)
            
            print(f"batch {i}/{num_train_data//BATCH_SIZE} acc:{train_acc}, loss:{train_loss}")

            # tensorboard
            # writer.add_scalar("train/batch/loss", train_loss, epoch)
            # writer.add_scalar("train/batch/acc", train_acc, epoch)

            train_loss.backward()
            optimizer.step()

        # test accuracy
        # total = 0
        # correct = 0
        # accuracy = []
        # for i, data in enumerate(test_dataloader, 0):
        #     inputs, labels = data

        print('epoch: %d/%d' %(epoch+1, params["num_epoch"]))

# %%
train(res50, params, criterion, optimizer, writer)
# Out:
# epoch 1.
# batch 0/56 acc:0.03125, loss:1.4752934575080872
# batch 1/56 acc:0.125, loss:1.5963193196803331
# batch 2/56 acc:0.3125, loss:1.396283870562911
# batch 3/56 acc:0.375, loss:1.4474241863936186
# batch 4/56 acc:0.375, loss:1.3513731686398387
# batch 5/56 acc:0.3125, loss:1.338305713608861
# batch 6/56 acc:0.3125, loss:1.3786549381911755
# batch 7/56 acc:0.375, loss:1.261145326308906
# batch 8/56 acc:0.3125, loss:1.3100623711943626
# batch 9/56 acc:0.40625, loss:1.2429860960692167
# batch 10/56 acc:0.375, loss:1.2855072319507599
# batch 11/56 acc:0.40625, loss:1.2385379180777818
# batch 12/56 acc:0.40625, loss:1.303305636625737
# batch 13/56 acc:0.46875, loss:1.313913755118847
# batch 14/56 acc:0.5, loss:1.1543026302824728
# batch 15/56 acc:0.1875, loss:1.3309241174720228
# batch 16/56 acc:0.1875, loss:1.4428047388792038
# batch 17/56 acc:0.40625, loss:1.3183533139526844
# batch 18/56 acc:0.46875, loss:1.255319306626916
# batch 19/56 acc:0.3125, loss:1.380321248434484
# batch 20/56 acc:0.4375, loss:1.136283092200756
# batch 21/56 acc:0.40625, loss:1.1824996713548899
# batch 22/56 acc:0.4375, loss:1.2161052813753486
# batch 23/56 acc:0.40625, loss:1.2811974557116628
# batch 24/56 acc:0.46875, loss:1.1944314315915108
# batch 25/56 acc:0.4375, loss:1.1573524586856365
# batch 26/56 acc:0.40625, loss:1.2091537956148386
# batch 27/56 acc:0.25, loss:1.3978582248091698
# batch 28/56 acc:0.3125, loss:1.288531070575118
# batch 29/56 acc:0.46875, loss:1.148517874069512
# batch 30/56 acc:0.34375, loss:1.3725719023495913
# batch 31/56 acc:0.25, loss:1.2596334535628557
# batch 32/56 acc:0.28125, loss:1.4436269141733646
# batch 33/56 acc:0.1875, loss:1.248642448335886
# batch 34/56 acc:0.28125, loss:1.2418727036565542
# batch 35/56 acc:0.34375, loss:1.2474102098494768
# batch 36/56 acc:0.5625, loss:1.1320556923747063
# batch 37/56 acc:0.3125, loss:1.254665986634791
# batch 38/56 acc:0.34375, loss:1.2736611664295197
# batch 39/56 acc:0.4375, loss:1.1540264878422022
# batch 40/56 acc:0.5625, loss:1.1331622675061226
# batch 41/56 acc:0.46875, loss:1.3828187827020884
# batch 42/56 acc:0.21875, loss:1.2839407781139016
# batch 43/56 acc:0.40625, loss:1.2676992751657963
# batch 44/56 acc:0.34375, loss:1.2582504376769066
# batch 45/56 acc:0.375, loss:1.3219960536807775
# batch 46/56 acc:0.40625, loss:1.3822430856525898
# batch 47/56 acc:0.46875, loss:1.139549108222127
# batch 48/56 acc:0.3125, loss:1.2947901394218206
# batch 49/56 acc:0.375, loss:1.4531276654452085
# batch 50/56 acc:0.34375, loss:1.347179189324379
# batch 51/56 acc:0.3125, loss:1.3303734604269266
# batch 52/56 acc:0.28125, loss:1.290984159335494
# batch 53/56 acc:0.53125, loss:1.2656370848417282
# batch 54/56 acc:0.5625, loss:1.1637170761823654
# batch 55/56 acc:0.40625, loss:1.1965342871844769
# batch 56/56 acc:0.5862069129943848, loss:1.1730902708809952
# epoch: 1/25
# epoch 2.
# batch 0/56 acc:0.59375, loss:1.1049808282405138
# batch 1/56 acc:0.34375, loss:1.2661124262958765
# batch 2/56 acc:0.34375, loss:1.3356547988951206
# batch 3/56 acc:0.34375, loss:1.2382156196981668
# batch 4/56 acc:0.34375, loss:1.3278565369546413
# batch 5/56 acc:0.34375, loss:1.3653393480926752
# batch 6/56 acc:0.28125, loss:1.1803119778633118
# batch 7/56 acc:0.4375, loss:1.2952844835817814
# batch 8/56 acc:0.46875, loss:1.152900442481041
# batch 9/56 acc:0.53125, loss:1.2102079223841429
# batch 10/56 acc:0.4375, loss:1.284726133570075
# batch 11/56 acc:0.46875, loss:1.1008056504651904
# batch 12/56 acc:0.40625, loss:1.2983903530985117
# batch 13/56 acc:0.375, loss:1.2190990233793855
# batch 14/56 acc:0.53125, loss:1.1916318354196846
# batch 15/56 acc:0.25, loss:1.457537766546011
# batch 16/56 acc:0.40625, loss:1.2024295553565025
# batch 17/56 acc:0.4375, loss:1.4114067582413554
# batch 18/56 acc:0.4375, loss:1.2024041302502155
# batch 19/56 acc:0.53125, loss:1.125846702605486
# batch 20/56 acc:0.46875, loss:1.0989025551825762
# batch 21/56 acc:0.40625, loss:1.288724111393094
# batch 22/56 acc:0.375, loss:1.2932482995092869
# batch 23/56 acc:0.46875, loss:1.220070719718933
# batch 24/56 acc:0.375, loss:1.2316585583612323
# batch 25/56 acc:0.375, loss:1.1726405415683985
# batch 26/56 acc:0.5, loss:1.124708360992372
# batch 27/56 acc:0.40625, loss:1.2750638909637928
# batch 28/56 acc:0.46875, loss:1.1074313409626484
# batch 29/56 acc:0.40625, loss:1.2219394631683826
# batch 30/56 acc:0.46875, loss:1.1020740866661072
# batch 31/56 acc:0.4375, loss:1.186208689585328
# batch 32/56 acc:0.3125, loss:1.4155618026852608
# batch 33/56 acc:0.34375, loss:1.247891005128622
# batch 34/56 acc:0.5, loss:1.1745715662837029
# batch 35/56 acc:0.40625, loss:1.1773377172648907
# batch 36/56 acc:0.40625, loss:1.2227148786187172
# batch 37/56 acc:0.53125, loss:1.1512580662965775
# batch 38/56 acc:0.375, loss:1.2699013529345393
# batch 39/56 acc:0.375, loss:1.2679085694253445
# batch 40/56 acc:0.5, loss:1.1444290112704039
# batch 41/56 acc:0.40625, loss:1.3538699466735125
# batch 42/56 acc:0.28125, loss:1.3243158739060163
# batch 43/56 acc:0.53125, loss:1.1758659379556775
# batch 44/56 acc:0.34375, loss:1.37899602483958
# batch 45/56 acc:0.3125, loss:1.2303614541888237
# batch 46/56 acc:0.4375, loss:1.1388152167201042
# batch 47/56 acc:0.21875, loss:1.3716550692915916
# batch 48/56 acc:0.375, loss:1.1354580912739038
# batch 49/56 acc:0.3125, loss:1.2694272473454475
# batch 50/56 acc:0.40625, loss:1.132750852033496
# batch 51/56 acc:0.28125, loss:1.1355119347572327
# batch 52/56 acc:0.375, loss:1.18194242939353
# batch 53/56 acc:0.34375, loss:1.4485786091536283
# batch 54/56 acc:0.28125, loss:1.2518981602042913
# batch 55/56 acc:0.46875, loss:1.3504565563052893
# batch 56/56 acc:0.4482758641242981, loss:1.2297124883224224
# epoch: 2/25
# epoch 3.
# batch 0/56 acc:0.3125, loss:1.3732780506834388
# batch 1/56 acc:0.46875, loss:1.3469681814312935
# batch 2/56 acc:0.3125, loss:1.242878183722496
# batch 3/56 acc:0.34375, loss:1.262754532508552
# batch 4/56 acc:0.375, loss:1.3198226895183325
# batch 5/56 acc:0.3125, loss:1.2383281271904707
# batch 6/56 acc:0.4375, loss:1.2130914516746998
# batch 7/56 acc:0.3125, loss:1.2573574092239141
# batch 8/56 acc:0.375, loss:1.2088732663542032
# batch 9/56 acc:0.4375, loss:1.231695793569088
# batch 10/56 acc:0.5625, loss:1.1772721838206053
# batch 11/56 acc:0.53125, loss:1.2071938067674637
# batch 12/56 acc:0.21875, loss:1.2777896579355001
# batch 13/56 acc:0.5625, loss:1.2473335824906826
# batch 14/56 acc:0.34375, loss:1.2736052107065916
# batch 15/56 acc:0.5, loss:1.113224247470498
# batch 16/56 acc:0.4375, loss:1.187139904126525
# batch 17/56 acc:0.40625, loss:1.272301323711872
# batch 18/56 acc:0.59375, loss:1.103519968688488
# batch 19/56 acc:0.34375, loss:1.2819453179836273
# batch 20/56 acc:0.40625, loss:1.2316220607608557
# batch 21/56 acc:0.46875, loss:1.1187287420034409
# batch 22/56 acc:0.5, loss:1.2722784914076328
# batch 23/56 acc:0.40625, loss:1.2574871378019452
# batch 24/56 acc:0.40625, loss:1.283550525084138
# batch 25/56 acc:0.4375, loss:1.1312466617673635
# batch 26/56 acc:0.40625, loss:1.1033948380500078
# batch 27/56 acc:0.53125, loss:1.240003252401948
# batch 28/56 acc:0.34375, loss:1.1401352658867836
# batch 29/56 acc:0.4375, loss:1.1279086880385876
# batch 30/56 acc:0.4375, loss:1.2716160845011473
# batch 31/56 acc:0.53125, loss:1.1860500555485487
# batch 32/56 acc:0.5625, loss:1.069218970835209
# batch 33/56 acc:0.375, loss:1.278935331851244
# batch 34/56 acc:0.34375, loss:1.2510301787406206
# batch 35/56 acc:0.46875, loss:1.0899641811847687
# batch 36/56 acc:0.53125, loss:1.1740295942872763
# batch 37/56 acc:0.53125, loss:1.2433849722146988
# batch 38/56 acc:0.28125, loss:1.2645082082599401
# batch 39/56 acc:0.28125, loss:1.2985031120479107
# batch 40/56 acc:0.40625, loss:1.3394995853304863
# batch 41/56 acc:0.5, loss:1.2500386256724596
# batch 42/56 acc:0.40625, loss:1.3647803105413914
# batch 43/56 acc:0.53125, loss:1.1495101042091846
# batch 44/56 acc:0.375, loss:1.2362101636826992
# batch 45/56 acc:0.5, loss:1.22101129591465
# batch 46/56 acc:0.15625, loss:1.397955035790801
# batch 47/56 acc:0.53125, loss:1.1561167854815722
# batch 48/56 acc:0.53125, loss:1.1462818458676338
# batch 49/56 acc:0.53125, loss:1.108561608940363
# batch 50/56 acc:0.375, loss:1.2811354119330645
# batch 51/56 acc:0.28125, loss:1.314913360401988
# batch 52/56 acc:0.5, loss:1.0473470566794276
# batch 53/56 acc:0.3125, loss:1.1853315951302648
# batch 54/56 acc:0.4375, loss:1.3808178128674626
# batch 55/56 acc:0.375, loss:1.2119929026812315
# batch 56/56 acc:0.41379308700561523, loss:1.2412467753065044
# epoch: 3/25
# epoch 4.
# batch 0/56 acc:0.4375, loss:1.170086001046002
# batch 1/56 acc:0.375, loss:1.2029099315404892
# batch 2/56 acc:0.375, loss:1.1396016916260123
# batch 3/56 acc:0.46875, loss:1.2380272075533867
# batch 4/56 acc:0.625, loss:1.138255967758596
# batch 5/56 acc:0.59375, loss:1.105340551584959
# batch 6/56 acc:0.375, loss:1.291392721235752
# batch 7/56 acc:0.4375, loss:1.1030593058094382
# batch 8/56 acc:0.4375, loss:1.1911914208903909
# batch 9/56 acc:0.5, loss:1.0329354451969266
# batch 10/56 acc:0.4375, loss:1.6085051745176315
# batch 11/56 acc:0.5, loss:1.115976944565773
# batch 12/56 acc:0.5, loss:1.180694518610835
# batch 13/56 acc:0.59375, loss:1.11763702519238
# batch 14/56 acc:0.25, loss:1.3034775611013174
# batch 15/56 acc:0.21875, loss:1.2973740799352527
# batch 16/56 acc:0.3125, loss:1.2119446992874146
# batch 17/56 acc:0.40625, loss:1.0745666157454252
# batch 18/56 acc:0.3125, loss:1.2369559844955802
# batch 19/56 acc:0.5, loss:1.0893736686557531
# batch 20/56 acc:0.53125, loss:1.0935604111291468
# batch 21/56 acc:0.3125, loss:1.3722558775916696
# batch 22/56 acc:0.46875, loss:1.2803833978250623
# batch 23/56 acc:0.34375, loss:1.384217156097293
# batch 24/56 acc:0.40625, loss:1.2678004633635283
# batch 25/56 acc:0.28125, loss:1.3634575447067618
# batch 26/56 acc:0.46875, loss:1.2515696994960308
# batch 27/56 acc:0.4375, loss:1.2058679200708866
# batch 28/56 acc:0.71875, loss:1.094886364415288
# batch 29/56 acc:0.375, loss:1.1516591627150774
# batch 30/56 acc:0.53125, loss:1.1448596557602286
# batch 31/56 acc:0.40625, loss:1.1604439541697502
# batch 32/56 acc:0.25, loss:1.1770264245569706
# batch 33/56 acc:0.375, loss:1.237415206618607
# batch 34/56 acc:0.5625, loss:1.2675881367176771
# batch 35/56 acc:0.53125, loss:1.2983287796378136
# batch 36/56 acc:0.40625, loss:1.2013249034062028
# batch 37/56 acc:0.34375, loss:1.2471055313944817
# batch 38/56 acc:0.40625, loss:1.2673020670190454
# batch 39/56 acc:0.46875, loss:1.2465013670735061
# batch 40/56 acc:0.5, loss:1.0797294517979026
# batch 41/56 acc:0.46875, loss:1.1128206150606275
# batch 42/56 acc:0.53125, loss:1.2595303012058139
# batch 43/56 acc:0.46875, loss:1.1784280557185411
# batch 44/56 acc:0.40625, loss:1.289001204073429
# batch 45/56 acc:0.34375, loss:1.2454312248155475
# batch 46/56 acc:0.40625, loss:1.2267019636929035
# batch 47/56 acc:0.5, loss:1.190199000760913
# batch 48/56 acc:0.46875, loss:1.1956454627215862
# batch 49/56 acc:0.3125, loss:1.3404632806777954
# batch 50/56 acc:0.4375, loss:1.2851111516356468
# batch 51/56 acc:0.34375, loss:1.1856349734589458
# batch 52/56 acc:0.28125, loss:1.3047519959509373
# batch 53/56 acc:0.5625, loss:1.0736827040091157
# batch 54/56 acc:0.5, loss:1.2203317638486624
# batch 55/56 acc:0.5, loss:1.1168405786156654
# batch 56/56 acc:0.5517241358757019, loss:1.0839798039403454
# epoch: 4/25
# epoch 5.
# batch 0/56 acc:0.4375, loss:1.1190437274053693
# batch 1/56 acc:0.28125, loss:1.1870056167244911
# batch 2/56 acc:0.4375, loss:1.2164661139249802
# batch 3/56 acc:0.53125, loss:1.1125646317377687
# batch 4/56 acc:0.3125, loss:1.4008620735257864
# batch 5/56 acc:0.46875, loss:1.1710839690640569
# batch 6/56 acc:0.5625, loss:1.0551070431247354
# batch 7/56 acc:0.5, loss:1.0581989288330078
# batch 8/56 acc:0.3125, loss:1.305636222474277
# batch 9/56 acc:0.5, loss:1.2087113559246063
# batch 10/56 acc:0.3125, loss:1.3208610247820616
# batch 11/56 acc:0.53125, loss:1.0888687670230865
# batch 12/56 acc:0.34375, loss:1.134997472167015
# batch 13/56 acc:0.46875, loss:1.1693698819726706
# batch 14/56 acc:0.40625, loss:1.1950100725516677
# batch 15/56 acc:0.53125, loss:1.1023989953100681
# batch 16/56 acc:0.53125, loss:1.0260700210928917
# batch 17/56 acc:0.375, loss:1.4703004769980907
# batch 18/56 acc:0.46875, loss:1.1713389856740832
# batch 19/56 acc:0.40625, loss:1.0941485483199358
# batch 20/56 acc:0.4375, loss:1.2000006772577763
# batch 21/56 acc:0.4375, loss:1.185899531468749
# batch 22/56 acc:0.40625, loss:1.3399223946034908
# batch 23/56 acc:0.40625, loss:1.3888782830908895
# batch 24/56 acc:0.40625, loss:1.199921348132193
# batch 25/56 acc:0.5625, loss:1.1501298071816564
# batch 26/56 acc:0.34375, loss:1.274196932092309
# batch 27/56 acc:0.34375, loss:1.4083931809291244
# batch 28/56 acc:0.53125, loss:0.9655303508043289
# batch 29/56 acc:0.375, loss:1.128729839809239
# batch 30/56 acc:0.53125, loss:1.0252765510231256
# batch 31/56 acc:0.375, loss:1.3701010774821043
# batch 32/56 acc:0.34375, loss:1.2449090322479606
# batch 33/56 acc:0.375, loss:1.2152916751801968
# batch 34/56 acc:0.3125, loss:1.3189881332218647
# batch 35/56 acc:0.5, loss:1.0917527237907052
# batch 36/56 acc:0.375, loss:1.2868815483525395
# batch 37/56 acc:0.375, loss:1.301470199599862
# batch 38/56 acc:0.34375, loss:1.1932593826204538
# batch 39/56 acc:0.28125, loss:1.2477418892085552
# batch 40/56 acc:0.5, loss:1.0801365058869123
# batch 41/56 acc:0.40625, loss:1.1794480178505182
# batch 42/56 acc:0.4375, loss:1.1904775630682707
# batch 43/56 acc:0.40625, loss:1.2408328279852867
# batch 44/56 acc:0.4375, loss:1.2642430551350117
# batch 45/56 acc:0.40625, loss:1.2982381731271744
# batch 46/56 acc:0.375, loss:1.1993766762316227
# batch 47/56 acc:0.375, loss:1.209153838455677
# batch 48/56 acc:0.59375, loss:1.1978027615696192
# batch 49/56 acc:0.40625, loss:1.1161503680050373
# batch 50/56 acc:0.40625, loss:1.2726336903870106
# batch 51/56 acc:0.34375, loss:1.151884427294135
# batch 52/56 acc:0.53125, loss:1.0455948002636433
# batch 53/56 acc:0.375, loss:1.3022556016221642
# batch 54/56 acc:0.4375, loss:1.180178189650178
# batch 55/56 acc:0.3125, loss:1.1537977033294737
# batch 56/56 acc:0.3448275923728943, loss:1.250429722769507
# epoch: 5/25
# epoch 6.
# batch 0/56 acc:0.53125, loss:0.9630219712853432
# batch 1/56 acc:0.4375, loss:1.2213336371351033
# batch 2/56 acc:0.53125, loss:1.0312493024393916
# batch 3/56 acc:0.6875, loss:1.0527752125635743
# batch 4/56 acc:0.4375, loss:1.1917198412120342
# batch 5/56 acc:0.375, loss:1.1873968606814742
# batch 6/56 acc:0.5, loss:1.0440009478479624
# batch 7/56 acc:0.53125, loss:1.0827886019833386
# batch 8/56 acc:0.3125, loss:1.2195592997595668
# batch 9/56 acc:0.4375, loss:1.0766142755746841
# batch 10/56 acc:0.40625, loss:1.2625696491450071
# batch 11/56 acc:0.625, loss:0.9946102336980402
# batch 12/56 acc:0.375, loss:1.3809017536696047
# batch 13/56 acc:0.4375, loss:1.0516134495846927
# batch 14/56 acc:0.5625, loss:1.2681127423420548
# batch 15/56 acc:0.375, loss:1.198674843646586
# batch 16/56 acc:0.46875, loss:1.1176996501162648
# batch 17/56 acc:0.40625, loss:1.1513106571510434
# batch 18/56 acc:0.40625, loss:1.107422759057954
# batch 19/56 acc:0.59375, loss:0.9823879161849618
# batch 20/56 acc:0.375, loss:1.2216450925916433
# batch 21/56 acc:0.34375, loss:1.4165582209825516
# batch 22/56 acc:0.4375, loss:1.2486177375540137
# batch 23/56 acc:0.34375, loss:1.3476409730501473
# batch 24/56 acc:0.53125, loss:1.1061205482110381
# batch 25/56 acc:0.5, loss:1.0448943036608398
# batch 26/56 acc:0.4375, loss:1.1290353401564062
# batch 27/56 acc:0.375, loss:1.142179471673444
# batch 28/56 acc:0.40625, loss:1.1351031358353794
# batch 29/56 acc:0.59375, loss:0.9799959450028837
# batch 30/56 acc:0.5625, loss:1.1267936156946234
# batch 31/56 acc:0.34375, loss:1.3229398541152477
# batch 32/56 acc:0.4375, loss:1.1980695372913033
# batch 33/56 acc:0.46875, loss:1.082811091793701
# batch 34/56 acc:0.34375, loss:1.2296585168223828
# batch 35/56 acc:0.5, loss:1.0113082171883434
# batch 36/56 acc:0.40625, loss:1.1168801109306514
# batch 37/56 acc:0.625, loss:0.9311285498552024
# batch 38/56 acc:0.53125, loss:1.0612444779835641
# batch 39/56 acc:0.5, loss:1.2520969590405002
# batch 40/56 acc:0.3125, loss:1.2158241865690798
# batch 41/56 acc:0.34375, loss:1.2323630282189697
# batch 42/56 acc:0.40625, loss:1.243956036749296
# batch 43/56 acc:0.5, loss:1.1155360392294824
# batch 44/56 acc:0.4375, loss:1.133477499242872
# batch 45/56 acc:0.46875, loss:1.1944410880096257
# batch 46/56 acc:0.625, loss:1.049911665963009
# batch 47/56 acc:0.5625, loss:1.0856895623728633
# batch 48/56 acc:0.40625, loss:1.1921890818048269
# batch 49/56 acc:0.5, loss:1.0587831115117297
# batch 50/56 acc:0.40625, loss:1.2198108872398734
# batch 51/56 acc:0.375, loss:1.1697825966402888
# batch 52/56 acc:0.25, loss:1.3398652395699173
# batch 53/56 acc:0.5625, loss:1.2382179264677688
# batch 54/56 acc:0.40625, loss:1.1443534651771188
# batch 55/56 acc:0.5, loss:1.1366280214861035
# batch 56/56 acc:0.48275861144065857, loss:1.075170941393951
# epoch: 6/25
# epoch 7.
# batch 0/56 acc:0.5625, loss:1.0255066761747003
# batch 1/56 acc:0.46875, loss:1.2829183721914887
# batch 2/56 acc:0.53125, loss:1.100268677342683
# batch 3/56 acc:0.5, loss:1.0746841682121158
# batch 4/56 acc:0.53125, loss:1.1258984794840217
# batch 5/56 acc:0.4375, loss:1.029794900212437
# batch 6/56 acc:0.3125, loss:1.1507585416547954
# batch 7/56 acc:0.34375, loss:1.0253267977386713
# batch 8/56 acc:0.5, loss:1.0886754852253944
# batch 9/56 acc:0.65625, loss:0.9504255224019289
# batch 10/56 acc:0.5, loss:1.124060076661408
# batch 11/56 acc:0.40625, loss:1.3249452442396432
# batch 12/56 acc:0.5625, loss:1.1875179205089808
# batch 13/56 acc:0.5, loss:0.9464813487138599
# batch 14/56 acc:0.59375, loss:1.0073421853594482
# batch 15/56 acc:0.46875, loss:1.3405908709391952
# batch 16/56 acc:0.5, loss:1.0413062951993197
# batch 17/56 acc:0.4375, loss:1.2145918642636389
# batch 18/56 acc:0.59375, loss:1.021126366511453
# batch 19/56 acc:0.5, loss:0.9657207702985033
# batch 20/56 acc:0.34375, loss:1.2463392835925333
# batch 21/56 acc:0.53125, loss:1.0677230891305953
# batch 22/56 acc:0.40625, loss:1.222682543535484
# batch 23/56 acc:0.625, loss:1.1255592741072178
# batch 24/56 acc:0.5, loss:1.3830399460857734
# batch 25/56 acc:0.5625, loss:1.041256488118961
# batch 26/56 acc:0.46875, loss:1.04179924694472
# batch 27/56 acc:0.46875, loss:1.3159987161052413
# batch 28/56 acc:0.46875, loss:1.1676882291067159
# batch 29/56 acc:0.4375, loss:1.1257193476776592
# batch 30/56 acc:0.34375, loss:1.4083245363435708
# batch 31/56 acc:0.53125, loss:1.1777174975723028
# batch 32/56 acc:0.4375, loss:1.1875793379440438
# batch 33/56 acc:0.65625, loss:0.968351123505272
# batch 34/56 acc:0.4375, loss:1.0443916040239856
# batch 35/56 acc:0.46875, loss:1.261014522286132
# batch 36/56 acc:0.6875, loss:0.827386534656398
# batch 37/56 acc:0.5, loss:1.0777631734963506
# batch 38/56 acc:0.46875, loss:1.0281861051917076
# batch 39/56 acc:0.4375, loss:1.2346121496520936
# batch 40/56 acc:0.5625, loss:1.0179431692231447
# batch 41/56 acc:0.53125, loss:1.184417916694656
# batch 42/56 acc:0.6875, loss:0.8956827918300405
# batch 43/56 acc:0.5625, loss:1.0274472262244672
# batch 44/56 acc:0.65625, loss:0.9331952972570434
# batch 45/56 acc:0.53125, loss:0.9980791639536619
# batch 46/56 acc:0.59375, loss:1.0362384798936546
# batch 47/56 acc:0.34375, loss:1.205274441279471
# batch 48/56 acc:0.65625, loss:0.8208838670980185
# batch 49/56 acc:0.53125, loss:1.0451263057766482
# batch 50/56 acc:0.5625, loss:0.9879377146717161
# batch 51/56 acc:0.59375, loss:0.9653469566255808
# batch 52/56 acc:0.59375, loss:0.9281367228832096
# batch 53/56 acc:0.5625, loss:1.1609916113666259
# batch 54/56 acc:0.53125, loss:1.1455081797030289
# batch 55/56 acc:0.4375, loss:1.1993304052157328
# batch 56/56 acc:0.5517241358757019, loss:1.0598103228217826
# epoch: 7/25
# epoch 8.
# batch 0/56 acc:0.59375, loss:1.0444756267170305
# batch 1/56 acc:0.53125, loss:1.0545372315245913
# batch 2/56 acc:0.5, loss:1.104647788903094
# batch 3/56 acc:0.625, loss:0.8903938868897967
# batch 4/56 acc:0.625, loss:0.9760109234121046
# batch 5/56 acc:0.5, loss:1.163039347193262
# batch 6/56 acc:0.375, loss:1.3090847356215818
# batch 7/56 acc:0.46875, loss:0.9977958189847413
# batch 8/56 acc:0.4375, loss:1.0793144424096681
# batch 9/56 acc:0.5625, loss:1.1821257652482018
# batch 10/56 acc:0.5625, loss:0.9584166259155609
# batch 11/56 acc:0.6875, loss:0.9270705766684841
# batch 12/56 acc:0.625, loss:1.029989882994414
# batch 13/56 acc:0.59375, loss:0.8139455807395279
# batch 14/56 acc:0.65625, loss:0.8825191651339992
# batch 15/56 acc:0.6875, loss:0.8586244021789753
# batch 16/56 acc:0.71875, loss:0.8399699390174646
# batch 17/56 acc:0.59375, loss:1.086080797482282
# batch 18/56 acc:0.4375, loss:1.4543193759163842
# batch 19/56 acc:0.59375, loss:1.0574759126029676
# batch 20/56 acc:0.625, loss:0.8250864340370754
# batch 21/56 acc:0.65625, loss:0.8440912973019294
# batch 22/56 acc:0.46875, loss:1.1690921309345867
# batch 23/56 acc:0.5625, loss:1.0722760378848761
# batch 24/56 acc:0.625, loss:1.055500529400888
# batch 25/56 acc:0.59375, loss:0.9784449786529876
# batch 26/56 acc:0.5625, loss:0.9261670871637762
# batch 27/56 acc:0.625, loss:0.7955628008348867
# batch 28/56 acc:0.65625, loss:0.927282557473518
# batch 29/56 acc:0.40625, loss:1.2719438392377924
# batch 30/56 acc:0.53125, loss:0.9776785309659317
# batch 31/56 acc:0.59375, loss:0.9869453136343509
# batch 32/56 acc:0.46875, loss:1.1648559016466606
# batch 33/56 acc:0.625, loss:0.96481561625842
# batch 34/56 acc:0.375, loss:1.029810604697559
# batch 35/56 acc:0.59375, loss:1.1723165063885972
# batch 36/56 acc:0.59375, loss:1.0829580576973967
# batch 37/56 acc:0.53125, loss:1.1060780337138567
# batch 38/56 acc:0.59375, loss:1.1337637682445347
# batch 39/56 acc:0.46875, loss:1.071182464598678
# batch 40/56 acc:0.5, loss:1.0465813641203567
# batch 41/56 acc:0.46875, loss:1.1127396174706519
# batch 42/56 acc:0.59375, loss:0.872863500204403
# batch 43/56 acc:0.625, loss:1.0126774538075551
# batch 44/56 acc:0.59375, loss:0.9709338557440788
# batch 45/56 acc:0.5, loss:1.0599166066385806
# batch 46/56 acc:0.625, loss:1.0496964692138135
# batch 47/56 acc:0.46875, loss:1.1388028109213337
# batch 48/56 acc:0.5, loss:1.136852461611852
# batch 49/56 acc:0.4375, loss:1.278934519039467
# batch 50/56 acc:0.5625, loss:1.0717686582356691
# batch 51/56 acc:0.34375, loss:1.0777575687970966
# batch 52/56 acc:0.59375, loss:1.0424783206544816
# batch 53/56 acc:0.53125, loss:1.0870024864561856
# batch 54/56 acc:0.53125, loss:0.9178096977993846
# batch 55/56 acc:0.4375, loss:1.114557062741369
# batch 56/56 acc:0.4482758641242981, loss:1.0714883736238396
# epoch: 8/25
# epoch 9.
# batch 0/56 acc:0.625, loss:1.0222997806267813
# batch 1/56 acc:0.53125, loss:0.9988146926043555
# batch 2/56 acc:0.6875, loss:0.8961302557727322
# batch 3/56 acc:0.46875, loss:0.9338438694830984
# batch 4/56 acc:0.5625, loss:0.9948446041089483
# batch 5/56 acc:0.53125, loss:1.0206635589129291
# batch 6/56 acc:0.625, loss:0.8902054842328653
# batch 7/56 acc:0.5, loss:1.0779948597191833
# batch 8/56 acc:0.6875, loss:0.9168988052988425
# batch 9/56 acc:0.53125, loss:1.0136602034181124
# batch 10/56 acc:0.46875, loss:1.0622992101270938
# batch 11/56 acc:0.6875, loss:0.8633543910254957
# batch 12/56 acc:0.53125, loss:1.1911111538247496
# batch 13/56 acc:0.59375, loss:0.8442688811628614
# batch 14/56 acc:0.5625, loss:0.8928433237888385
# batch 15/56 acc:0.375, loss:1.2037939891861242
# batch 16/56 acc:0.375, loss:1.2812848862959072
# batch 17/56 acc:0.59375, loss:1.2227525303278526
# batch 18/56 acc:0.53125, loss:0.9976235498179449
# batch 19/56 acc:0.40625, loss:1.2625522914386238
# batch 20/56 acc:0.59375, loss:0.867387100297492
# batch 21/56 acc:0.625, loss:0.8340817137504928
# batch 22/56 acc:0.625, loss:0.9608218435751041
# batch 23/56 acc:0.53125, loss:0.9905995151930256
# batch 24/56 acc:0.5, loss:1.0527141552884132
# batch 25/56 acc:0.5, loss:1.0826073427815572
# batch 26/56 acc:0.6875, loss:0.7880787019239506
# batch 27/56 acc:0.53125, loss:1.0378530566813424
# batch 28/56 acc:0.59375, loss:0.9199879787192913
# batch 29/56 acc:0.5, loss:1.1481318476362503
# batch 30/56 acc:0.40625, loss:1.1022184058383573
# batch 31/56 acc:0.65625, loss:0.9723164685419761
# batch 32/56 acc:0.65625, loss:0.8432933382573538
# batch 33/56 acc:0.71875, loss:1.0022771835501771
# batch 34/56 acc:0.65625, loss:0.7962804947746918
# batch 35/56 acc:0.53125, loss:1.00023356085876
# batch 36/56 acc:0.5625, loss:0.9034542569715995
# batch 37/56 acc:0.5, loss:1.0033269256236963
# batch 38/56 acc:0.625, loss:1.005408369936049
# batch 39/56 acc:0.46875, loss:0.9829534590244293
# batch 40/56 acc:0.65625, loss:1.0235299122869037
# batch 41/56 acc:0.625, loss:0.972853654413484
# batch 42/56 acc:0.53125, loss:1.1096735626633745
# batch 43/56 acc:0.40625, loss:1.1323183686472476
# batch 44/56 acc:0.5625, loss:0.9469696899759583
# batch 45/56 acc:0.625, loss:0.9631361908977851
# batch 46/56 acc:0.625, loss:0.8772942025680095
# batch 47/56 acc:0.5625, loss:1.1189108036924154
# batch 48/56 acc:0.5625, loss:0.81646913359873
# batch 49/56 acc:0.71875, loss:0.7207016807515174
# batch 50/56 acc:0.59375, loss:0.871843482949771
# batch 51/56 acc:0.71875, loss:0.802661196095869
# batch 52/56 acc:0.5625, loss:1.128448965959251
# batch 53/56 acc:0.5625, loss:1.0584643112961203
# batch 54/56 acc:0.625, loss:0.9809831015300006
# batch 55/56 acc:0.71875, loss:0.789223306113854
# batch 56/56 acc:0.5517241358757019, loss:1.0737252898257355
# epoch: 9/25
# epoch 10.
# batch 0/56 acc:0.46875, loss:1.1378002506680787
# batch 1/56 acc:0.65625, loss:0.9102954373229295
# batch 2/56 acc:0.6875, loss:0.9046259736642241
# batch 3/56 acc:0.46875, loss:1.1031206452753395
# batch 4/56 acc:0.65625, loss:0.8596172907855362
# batch 5/56 acc:0.6875, loss:0.7256588366581127
# batch 6/56 acc:0.53125, loss:1.1152920331805944
# batch 7/56 acc:0.53125, loss:1.0218912285054103
# batch 8/56 acc:0.53125, loss:1.030047222506255
# batch 9/56 acc:0.6875, loss:0.8792300121276639
# batch 10/56 acc:0.8125, loss:0.8290759075898677
# batch 11/56 acc:0.5, loss:1.1139507483458146
# batch 12/56 acc:0.8125, loss:0.6798941087909043
# batch 13/56 acc:0.53125, loss:0.9966485627810471
# batch 14/56 acc:0.5625, loss:0.9494763205293566
# batch 15/56 acc:0.53125, loss:0.9274592174915597
# batch 16/56 acc:0.5, loss:1.1397853468661197
# batch 17/56 acc:0.5625, loss:0.9485391266061924
# batch 18/56 acc:0.5, loss:0.9797010569018312
# batch 19/56 acc:0.71875, loss:0.7842879903037101
# batch 20/56 acc:0.65625, loss:0.8856643083854578
# batch 21/56 acc:0.65625, loss:0.8921992206596769
# batch 22/56 acc:0.625, loss:0.8689669084269553
# batch 23/56 acc:0.59375, loss:0.8744849672075361
# batch 24/56 acc:0.59375, loss:1.1412584365461953
# batch 25/56 acc:0.5625, loss:1.0221797394915484
# batch 26/56 acc:0.625, loss:0.8467643010662869
# batch 27/56 acc:0.59375, loss:0.7989908212912269
# batch 28/56 acc:0.78125, loss:0.7282685434329323
# batch 29/56 acc:0.375, loss:1.1052376490843017
# batch 30/56 acc:0.53125, loss:0.9901689164689742
# batch 31/56 acc:0.5625, loss:0.880498502170667
# batch 32/56 acc:0.65625, loss:0.9879610251664417
# batch 33/56 acc:0.625, loss:0.9155330804205732
# batch 34/56 acc:0.71875, loss:0.9042160827666521
# batch 35/56 acc:0.53125, loss:1.025268622243857
# batch 36/56 acc:0.6875, loss:0.8652331062767189
# batch 37/56 acc:0.65625, loss:0.9694042595401697
# batch 38/56 acc:0.75, loss:0.7470110053691315
# batch 39/56 acc:0.6875, loss:0.732579088966304
# batch 40/56 acc:0.625, loss:0.7774623575242003
# batch 41/56 acc:0.5625, loss:0.9041103230410954
# batch 42/56 acc:0.71875, loss:0.9353033274019253
# batch 43/56 acc:0.65625, loss:0.9985399410506943
# batch 44/56 acc:0.65625, loss:0.8633234779845225
# batch 45/56 acc:0.5625, loss:1.1296377436519833
# batch 46/56 acc:0.5625, loss:0.9760356346523622
# batch 47/56 acc:0.65625, loss:0.9046161247970304
# batch 48/56 acc:0.5625, loss:1.3736415432649665
# batch 49/56 acc:0.5625, loss:0.9045013292343356
# batch 50/56 acc:0.625, loss:0.9451951992814429
# batch 51/56 acc:0.65625, loss:0.9300673986435868
# batch 52/56 acc:0.6875, loss:0.8476721067563631
# batch 53/56 acc:0.53125, loss:0.9960239715292118
# batch 54/56 acc:0.53125, loss:0.876225846237503
# batch 55/56 acc:0.59375, loss:0.8781004927586764
# batch 56/56 acc:0.41379308700561523, loss:1.126961979886581
# epoch: 10/25
# epoch 11.
# batch 0/56 acc:0.625, loss:1.0685180015861988
# batch 1/56 acc:0.59375, loss:0.9571196585893631
# batch 2/56 acc:0.65625, loss:0.8488175391685218
# batch 3/56 acc:0.5625, loss:1.037152101751417
# batch 4/56 acc:0.6875, loss:0.8357537114061415
# batch 5/56 acc:0.53125, loss:0.9824842114467174
# batch 6/56 acc:0.46875, loss:1.03475099359639
# batch 7/56 acc:0.71875, loss:0.781737333163619
# batch 8/56 acc:0.5, loss:1.2358327615074813
# batch 9/56 acc:0.5625, loss:0.8898737083654851
# batch 10/56 acc:0.5625, loss:1.0436667720787227
# batch 11/56 acc:0.65625, loss:0.800112746655941
# batch 12/56 acc:0.625, loss:0.8980993642471731
# batch 13/56 acc:0.78125, loss:0.8038806000258774
# batch 14/56 acc:0.75, loss:0.7789901953656226
# batch 15/56 acc:0.65625, loss:0.9120500991120934
# batch 16/56 acc:0.65625, loss:0.9595994213595986
# batch 17/56 acc:0.6875, loss:0.7163773011416197
# batch 18/56 acc:0.6875, loss:0.7457785600563511
# batch 19/56 acc:0.5625, loss:0.96615573996678
# batch 20/56 acc:0.6875, loss:0.7067550412612036
# batch 21/56 acc:0.65625, loss:0.9093054464901797
# batch 22/56 acc:0.65625, loss:0.793648719904013
# batch 23/56 acc:0.71875, loss:0.8623946396401152
# batch 24/56 acc:0.59375, loss:0.9312252528616227
# batch 25/56 acc:0.625, loss:0.9249136957805604
# batch 26/56 acc:0.5625, loss:1.0182759810704738
# batch 27/56 acc:0.65625, loss:0.9085076621267945
# batch 28/56 acc:0.78125, loss:0.7622152380645275
# batch 29/56 acc:0.6875, loss:0.8385401522973552
# batch 30/56 acc:0.59375, loss:0.9928804145311005
# batch 31/56 acc:0.625, loss:0.8492676808964461
# batch 32/56 acc:0.5, loss:1.249118635605555
# batch 33/56 acc:0.6875, loss:1.013923473248724
# batch 34/56 acc:0.625, loss:0.9698522436665371
# batch 35/56 acc:0.59375, loss:0.942538442555815
# batch 36/56 acc:0.59375, loss:0.9402731547597796
# batch 37/56 acc:0.625, loss:0.9072306719608605
# batch 38/56 acc:0.59375, loss:0.8651475395599846
# batch 39/56 acc:0.625, loss:0.8248807107447647
# batch 40/56 acc:0.6875, loss:0.8042110455571674
# batch 41/56 acc:0.6875, loss:0.7214431745233014
# batch 42/56 acc:0.5, loss:0.9926658978074556
# batch 43/56 acc:0.46875, loss:1.1702583821024746
# batch 44/56 acc:0.5625, loss:0.9109473347634776
# batch 45/56 acc:0.53125, loss:1.1747464732616208
# batch 46/56 acc:0.6875, loss:0.7529729364905506
# batch 47/56 acc:0.78125, loss:0.8139178738201736
# batch 48/56 acc:0.5625, loss:1.0025051239063032
# batch 49/56 acc:0.53125, loss:1.027803543227492
# batch 50/56 acc:0.6875, loss:0.6440397674741689
# batch 51/56 acc:0.59375, loss:1.1266071436693892
# batch 52/56 acc:0.53125, loss:1.0849164405663032
# batch 53/56 acc:0.625, loss:0.9109171816380695
# batch 54/56 acc:0.71875, loss:0.7412849357933737
# batch 55/56 acc:0.625, loss:0.8558301248704083
# batch 56/56 acc:0.5862069129943848, loss:0.9127560527674083
# epoch: 11/25
# epoch 12.
# batch 0/56 acc:0.59375, loss:0.9182024163019378
# batch 1/56 acc:0.65625, loss:0.8594699709428824
# batch 2/56 acc:0.71875, loss:0.7378284327569418
# batch 3/56 acc:0.5625, loss:1.024355102534173
# batch 4/56 acc:0.71875, loss:0.8102426763798576
# batch 5/56 acc:0.71875, loss:0.793384683522163
# batch 6/56 acc:0.59375, loss:0.9295715831103735
# batch 7/56 acc:0.53125, loss:0.8142511720652692
# batch 8/56 acc:0.65625, loss:0.8153566768742166
# batch 9/56 acc:0.65625, loss:0.8143426215683576
# batch 10/56 acc:0.625, loss:0.9876115018068958
# batch 11/56 acc:0.46875, loss:1.1612107263572398
# batch 12/56 acc:0.59375, loss:0.9324438710391405
# batch 13/56 acc:0.65625, loss:0.8220327998133143
# batch 14/56 acc:0.625, loss:0.8127582023735158
# batch 15/56 acc:0.625, loss:0.8325816884207597
# batch 16/56 acc:0.6875, loss:0.7954813523538178
# batch 17/56 acc:0.59375, loss:1.1629427635343745
# batch 18/56 acc:0.78125, loss:0.7444402927576448
# batch 19/56 acc:0.59375, loss:0.8033934637496714
# batch 20/56 acc:0.65625, loss:0.8642487327160779
# batch 21/56 acc:0.65625, loss:0.8238292586174794
# batch 22/56 acc:0.6875, loss:0.8761552344367374
# batch 23/56 acc:0.6875, loss:0.8771698787750211
# batch 24/56 acc:0.71875, loss:0.5812068753875792
# batch 25/56 acc:0.71875, loss:0.8177142132335575
# batch 26/56 acc:0.625, loss:0.9335367066669278
# batch 27/56 acc:0.5625, loss:0.9420106044854037
# batch 28/56 acc:0.65625, loss:0.8007618545379955
# batch 29/56 acc:0.625, loss:0.9046713167335838
# batch 30/56 acc:0.6875, loss:0.700435822684085
# batch 31/56 acc:0.75, loss:0.745141766499728
# batch 32/56 acc:0.71875, loss:0.8371868515387177
# batch 33/56 acc:0.75, loss:0.8183137342566624
# batch 34/56 acc:0.65625, loss:0.9299452402046882
# batch 35/56 acc:0.5625, loss:0.9642584031098522
# batch 36/56 acc:0.65625, loss:0.9202823428204283
# batch 37/56 acc:0.5625, loss:0.95641989010619
# batch 38/56 acc:0.65625, loss:0.8996158903464675
# batch 39/56 acc:0.75, loss:0.6850950238876976
# batch 40/56 acc:0.625, loss:0.9978589871898293
# batch 41/56 acc:0.71875, loss:0.799955120193772
# batch 42/56 acc:0.5625, loss:1.029891596059315
# batch 43/56 acc:0.71875, loss:0.8739026710391045
# batch 44/56 acc:0.65625, loss:0.9082040989305824
# batch 45/56 acc:0.71875, loss:0.8260636175982654
# batch 46/56 acc:0.5, loss:1.1327870468376204
# batch 47/56 acc:0.59375, loss:1.1220136993797496
# batch 48/56 acc:0.5625, loss:0.9752017060527578
# batch 49/56 acc:0.53125, loss:0.9833927131257951
# batch 50/56 acc:0.6875, loss:0.8563484417973086
# batch 51/56 acc:0.65625, loss:0.8476942346896976
# batch 52/56 acc:0.75, loss:0.734462697757408
# batch 53/56 acc:0.625, loss:0.8528311932459474
# batch 54/56 acc:0.625, loss:0.9133213984314352
# batch 55/56 acc:0.71875, loss:0.7349814709741622
# batch 56/56 acc:0.6206896305084229, loss:0.8959624055644562
# epoch: 12/25
# epoch 13.
# batch 0/56 acc:0.6875, loss:0.8729131309082732
# batch 1/56 acc:0.6875, loss:0.8135032298741862
# batch 2/56 acc:0.625, loss:0.9477799375308678
# batch 3/56 acc:0.8125, loss:0.6769140684045851
# batch 4/56 acc:0.71875, loss:0.7538264964241534
# batch 5/56 acc:0.71875, loss:0.7703506235266104
# batch 6/56 acc:0.5625, loss:0.9250275202211924
# batch 7/56 acc:0.625, loss:1.0304163971159142
# batch 8/56 acc:0.6875, loss:0.8447198259527795
# batch 9/56 acc:0.5, loss:1.0102588052977808
# batch 10/56 acc:0.6875, loss:0.7386761812667828
# batch 11/56 acc:0.5625, loss:0.9976363941677846
# batch 12/56 acc:0.75, loss:0.8317874491622206
# batch 13/56 acc:0.5625, loss:1.1709899413690437
# batch 14/56 acc:0.71875, loss:0.6972624478512444
# batch 15/56 acc:0.625, loss:0.7566778159816749
# batch 16/56 acc:0.5625, loss:0.8667802414565813
# batch 17/56 acc:0.8125, loss:0.7002972380723804
# batch 18/56 acc:0.75, loss:0.8029458639211953
# batch 19/56 acc:0.59375, loss:0.9770816614036448
# batch 20/56 acc:0.59375, loss:0.9716256851133949
# batch 21/56 acc:0.71875, loss:0.7241506660429877
# batch 22/56 acc:0.65625, loss:0.7649611952510895
# batch 23/56 acc:0.75, loss:0.7851504861791909
# batch 24/56 acc:0.65625, loss:0.8260996008466464
# batch 25/56 acc:0.625, loss:1.293570732617809
# batch 26/56 acc:0.6875, loss:0.8504174725676421
# batch 27/56 acc:0.59375, loss:1.128116352516372
# batch 28/56 acc:0.84375, loss:0.5462997688682663
# batch 29/56 acc:0.75, loss:0.7079454037520918
# batch 30/56 acc:0.5, loss:0.9110355163284112
# batch 31/56 acc:0.59375, loss:0.8695168598787859
# batch 32/56 acc:0.65625, loss:0.9181969179189764
# batch 33/56 acc:0.75, loss:0.6246549061615951
# batch 34/56 acc:0.71875, loss:0.6944760208134539
# batch 35/56 acc:0.6875, loss:0.8286754048313014
# batch 36/56 acc:0.65625, loss:0.7663652867777273
# batch 37/56 acc:0.625, loss:0.9183436415623873
# batch 38/56 acc:0.53125, loss:1.1367843228508718
# batch 39/56 acc:0.6875, loss:0.8232437609112822
# batch 40/56 acc:0.75, loss:0.7019115623552352
# batch 41/56 acc:0.65625, loss:0.8476434467011131
# batch 42/56 acc:0.53125, loss:1.204363134515006
# batch 43/56 acc:0.65625, loss:0.8727104968274944
# batch 44/56 acc:0.6875, loss:0.9883435934316367
# batch 45/56 acc:0.5625, loss:1.1142164730117656
# batch 46/56 acc:0.75, loss:0.6560385199845769
# batch 47/56 acc:0.65625, loss:0.9364804024808109
# batch 48/56 acc:0.46875, loss:1.0723944915807806
# batch 49/56 acc:0.8125, loss:0.7398122988524847
# batch 50/56 acc:0.5, loss:0.9456549740862101
# batch 51/56 acc:0.65625, loss:0.9250713129295036
# batch 52/56 acc:0.71875, loss:0.7323161356616765
# batch 53/56 acc:0.6875, loss:0.8226648967829533
# batch 54/56 acc:0.5625, loss:0.8432978389319032
# batch 55/56 acc:0.71875, loss:0.7876276845345274
# batch 56/56 acc:0.6896551847457886, loss:0.8372157993244713
# epoch: 13/25
# epoch 14.
# batch 0/56 acc:0.75, loss:0.7849371656775475
# batch 1/56 acc:0.59375, loss:0.8899926025187597
# batch 2/56 acc:0.75, loss:0.7922074106754735
# batch 3/56 acc:0.5, loss:1.1239068661816418
# batch 4/56 acc:0.53125, loss:0.9600079871015623
# batch 5/56 acc:0.65625, loss:0.7992587827611715
# batch 6/56 acc:0.75, loss:0.6668670430080965
# batch 7/56 acc:0.625, loss:1.0020170120988041
# batch 8/56 acc:0.78125, loss:0.6891425247304142
# batch 9/56 acc:0.6875, loss:0.8262751499423757
# batch 10/56 acc:0.5, loss:1.0766274130437523
# batch 11/56 acc:0.59375, loss:0.8314363012323156
# batch 12/56 acc:0.65625, loss:0.8971049254760146
# batch 13/56 acc:0.78125, loss:0.6308443914167583
# batch 14/56 acc:0.71875, loss:0.9128618928370997
# batch 15/56 acc:0.75, loss:0.7540851830272004
# batch 16/56 acc:0.625, loss:0.8105091012548655
# batch 17/56 acc:0.6875, loss:0.7703698046389036
# batch 18/56 acc:0.6875, loss:0.7804118237691
# batch 19/56 acc:0.8125, loss:0.7270548560190946
# batch 20/56 acc:0.6875, loss:0.7984020652947947
# batch 21/56 acc:0.6875, loss:0.8478061293135397
# batch 22/56 acc:0.6875, loss:0.8310630970518105
# batch 23/56 acc:0.9375, loss:0.45604683086276054
# batch 24/56 acc:0.84375, loss:0.6796064810478128
# batch 25/56 acc:0.75, loss:0.6715810603345744
# batch 26/56 acc:0.71875, loss:0.7214759978814982
# batch 27/56 acc:0.5625, loss:0.9199995878152549
# batch 28/56 acc:0.6875, loss:0.8013793770223856
# batch 29/56 acc:0.625, loss:0.8953919337363914
# batch 30/56 acc:0.625, loss:0.7200668940786272
# batch 31/56 acc:0.65625, loss:0.9927633031620644
# batch 32/56 acc:0.75, loss:0.6804033216321841
# batch 33/56 acc:0.78125, loss:0.6193599551043008
# batch 34/56 acc:0.59375, loss:0.9930915198929142
# batch 35/56 acc:0.625, loss:0.8811044013709761
# batch 36/56 acc:0.8125, loss:0.7333998566609807
# batch 37/56 acc:0.59375, loss:1.0780367418192327
# batch 38/56 acc:0.6875, loss:0.8639100696891546
# batch 39/56 acc:0.65625, loss:0.8196648919838481
# batch 40/56 acc:0.75, loss:0.7284081777906977
# batch 41/56 acc:0.6875, loss:0.7901679982314818
# batch 42/56 acc:0.65625, loss:0.7692305704113096
# batch 43/56 acc:0.625, loss:0.77529604366282
# batch 44/56 acc:0.84375, loss:0.6644230922684073
# batch 45/56 acc:0.71875, loss:0.8012825137120672
# batch 46/56 acc:0.59375, loss:0.9613435609498993
# batch 47/56 acc:0.65625, loss:0.7810344271711074
# batch 48/56 acc:0.6875, loss:0.8660055143991485
# batch 49/56 acc:0.84375, loss:0.5260169722605497
# batch 50/56 acc:0.6875, loss:0.8257174042519182
# batch 51/56 acc:0.65625, loss:0.9184019775129855
# batch 52/56 acc:0.59375, loss:0.9703302677953616
# batch 53/56 acc:0.6875, loss:0.8355531187262386
# batch 54/56 acc:0.65625, loss:1.0232482604915276
# batch 55/56 acc:0.625, loss:0.9132974547683261
# batch 56/56 acc:0.7241379022598267, loss:0.8022227630918396
# epoch: 14/25
# epoch 15.
# batch 0/56 acc:0.75, loss:0.8633450656197965
# batch 1/56 acc:0.59375, loss:0.940624636830762
# batch 2/56 acc:0.71875, loss:0.6501387145835906
# batch 3/56 acc:0.71875, loss:0.7646761622745544
# batch 4/56 acc:0.78125, loss:0.6001739203929901
# batch 5/56 acc:0.65625, loss:0.8853770249988884
# batch 6/56 acc:0.65625, loss:0.9331764845410362
# batch 7/56 acc:0.8125, loss:0.7017646789317951
# batch 8/56 acc:0.75, loss:0.7044696866068989
# batch 9/56 acc:0.65625, loss:0.7966182986274362
# batch 10/56 acc:0.6875, loss:0.9047872433438897
# batch 11/56 acc:0.6875, loss:0.7787037326488644
# batch 12/56 acc:0.75, loss:0.6447265904862434
# batch 13/56 acc:0.6875, loss:0.9945276288781315
# batch 14/56 acc:0.78125, loss:0.6502740621799603
# batch 15/56 acc:0.59375, loss:1.0282143860822544
# batch 16/56 acc:0.75, loss:0.7030481118708849
# batch 17/56 acc:0.78125, loss:0.7271314836107194
# batch 18/56 acc:0.6875, loss:0.7449290509102866
# batch 19/56 acc:0.71875, loss:0.756367209367454
# batch 20/56 acc:0.625, loss:0.895060162525624
# batch 21/56 acc:0.8125, loss:0.5208815616788343
# batch 22/56 acc:0.75, loss:0.6722169149434194
# batch 23/56 acc:0.8125, loss:0.6125653751078062
# batch 24/56 acc:0.625, loss:0.9106771565566305
# batch 25/56 acc:0.5625, loss:0.9019896224490367
# batch 26/56 acc:0.75, loss:0.7329236694495194
# batch 27/56 acc:0.75, loss:0.7592491990653798
# batch 28/56 acc:0.5, loss:1.2226524986763252
# batch 29/56 acc:0.625, loss:1.0198039237875491
# batch 30/56 acc:0.59375, loss:0.9717452603799757
# batch 31/56 acc:0.8125, loss:0.624439181498019
# batch 32/56 acc:0.65625, loss:0.8524292075599078
# batch 33/56 acc:0.78125, loss:0.558504476910457
# batch 34/56 acc:0.65625, loss:0.9250104544626083
# batch 35/56 acc:0.84375, loss:0.558954232808901
# batch 36/56 acc:0.59375, loss:0.9848860677448101
# batch 37/56 acc:0.625, loss:0.7696961163892411
# batch 38/56 acc:0.71875, loss:0.6084896454703994
# batch 39/56 acc:0.75, loss:0.6973824794404209
# batch 40/56 acc:0.625, loss:0.8046876667067409
# batch 41/56 acc:0.78125, loss:0.6534941364370752
# batch 42/56 acc:0.75, loss:0.6981372553855181
# batch 43/56 acc:0.6875, loss:0.7533685435773805
# batch 44/56 acc:0.65625, loss:0.7439582993392833
# batch 45/56 acc:0.5, loss:1.2177294286666438
# batch 46/56 acc:0.75, loss:0.8010533728811424
# batch 47/56 acc:0.71875, loss:0.8527288510231301
# batch 48/56 acc:0.59375, loss:0.946113929967396
# batch 49/56 acc:0.59375, loss:1.1236349815444555
# batch 50/56 acc:0.5625, loss:1.1501709641015623
# batch 51/56 acc:0.8125, loss:0.5865893590380438
# batch 52/56 acc:0.8125, loss:0.7126665799878538
# batch 53/56 acc:0.71875, loss:0.7321341607021168
# batch 54/56 acc:0.53125, loss:1.016264581703581
# batch 55/56 acc:0.6875, loss:0.8896648458903655
# batch 56/56 acc:0.6896551847457886, loss:0.9409359811708845
# epoch: 15/25
# epoch 16.
# batch 0/56 acc:0.71875, loss:0.8445322393672541
# batch 1/56 acc:0.59375, loss:0.8735747905448079
# batch 2/56 acc:0.46875, loss:0.9534338040975854
# batch 3/56 acc:0.6875, loss:0.85362599324435
# batch 4/56 acc:0.875, loss:0.5544566800817847
# batch 5/56 acc:0.75, loss:0.7395415714709088
# batch 6/56 acc:0.71875, loss:0.7170454303268343
# batch 7/56 acc:0.625, loss:0.9575286604231223
# batch 8/56 acc:0.59375, loss:0.8725049621425569
# batch 9/56 acc:0.6875, loss:0.8667441293364391
# batch 10/56 acc:0.75, loss:0.6993873574538156
# batch 11/56 acc:0.75, loss:0.7575686859199777
# batch 12/56 acc:0.71875, loss:0.7400230483617634
# batch 13/56 acc:0.65625, loss:0.7568792811362073
# batch 14/56 acc:0.59375, loss:0.9153470399323851
# batch 15/56 acc:0.625, loss:0.8203226251062006
# batch 16/56 acc:0.6875, loss:0.8992898801807314
# batch 17/56 acc:0.5625, loss:0.973281446902547
# batch 18/56 acc:0.65625, loss:0.92389362573158
# batch 19/56 acc:0.71875, loss:0.7084285349119455
# batch 20/56 acc:0.75, loss:0.7149111704202369
# batch 21/56 acc:0.6875, loss:0.765963070676662
# batch 22/56 acc:0.625, loss:0.8841368652647361
# batch 23/56 acc:0.78125, loss:0.6248317449353635
# batch 24/56 acc:0.71875, loss:0.7188516455935314
# batch 25/56 acc:0.6875, loss:0.7087625075364485
# batch 26/56 acc:0.6875, loss:0.8990240576677024
# batch 27/56 acc:0.78125, loss:0.5585372751811519
# batch 28/56 acc:0.6875, loss:0.894701884360984
# batch 29/56 acc:0.59375, loss:1.047299984144047
# batch 30/56 acc:0.6875, loss:0.8775401286548004
# batch 31/56 acc:0.8125, loss:0.5669437971664593
# batch 32/56 acc:0.78125, loss:0.5478860581060871
# batch 33/56 acc:0.5625, loss:0.7518170635448769
# batch 34/56 acc:0.78125, loss:0.6530561572872102
# batch 35/56 acc:0.6875, loss:0.9181584517937154
# batch 36/56 acc:0.75, loss:0.7456149427453056
# batch 37/56 acc:0.875, loss:0.5473664313321933
# batch 38/56 acc:0.625, loss:0.9987551452359185
# batch 39/56 acc:0.71875, loss:0.6094422024907544
# batch 40/56 acc:0.6875, loss:0.9144344283849932
# batch 41/56 acc:0.75, loss:0.6193766981596127
# batch 42/56 acc:0.71875, loss:0.7194490868132561
# batch 43/56 acc:0.75, loss:0.8129679862759076
# batch 44/56 acc:0.6875, loss:0.7526509897143114
# batch 45/56 acc:0.71875, loss:0.7593010910204612
# batch 46/56 acc:0.59375, loss:0.8339106968196575
# batch 47/56 acc:0.6875, loss:0.6609531377325766
# batch 48/56 acc:0.75, loss:0.6624762502033263
# batch 49/56 acc:0.6875, loss:0.7787709159019869
# batch 50/56 acc:0.78125, loss:0.6481538570369594
# batch 51/56 acc:0.65625, loss:0.9084839874412864
# batch 52/56 acc:0.59375, loss:0.9429796400363557
# batch 53/56 acc:0.65625, loss:0.9221591913374141
# batch 54/56 acc:0.625, loss:0.9259970734128729
# batch 55/56 acc:0.78125, loss:0.7190409826580435
# batch 56/56 acc:0.6551724076271057, loss:0.8293043938304844
# epoch: 16/25
# epoch 17.
# batch 0/56 acc:0.75, loss:0.7029297075932845
# batch 1/56 acc:0.625, loss:0.7541446802206337
# batch 2/56 acc:0.625, loss:0.8697619249287527
# batch 3/56 acc:0.71875, loss:0.782460993854329
# batch 4/56 acc:0.6875, loss:0.7849912488018163
# batch 5/56 acc:0.78125, loss:0.7362308885785751
# batch 6/56 acc:0.71875, loss:0.7337348505971022
# batch 7/56 acc:0.71875, loss:0.6446824237355031
# batch 8/56 acc:0.6875, loss:0.7965567680075765
# batch 9/56 acc:0.78125, loss:0.698425798502285
# batch 10/56 acc:0.59375, loss:1.0863683720235713
# batch 11/56 acc:0.625, loss:0.8897317928494886
# batch 12/56 acc:0.75, loss:0.716546235489659
# batch 13/56 acc:0.6875, loss:0.7429647180251777
# batch 14/56 acc:0.5, loss:1.1367618523654528
# batch 15/56 acc:0.65625, loss:0.8278338137897663
# batch 16/56 acc:0.78125, loss:0.6716865686466917
# batch 17/56 acc:0.75, loss:0.6422011725371704
# batch 18/56 acc:0.6875, loss:0.8219544916646555
# batch 19/56 acc:0.84375, loss:0.5885838047252037
# batch 20/56 acc:0.65625, loss:0.8757295814284589
# batch 21/56 acc:0.75, loss:0.6499392988334876
# batch 22/56 acc:0.53125, loss:0.9188964123604819
# batch 23/56 acc:0.625, loss:1.4516708760056645
# batch 24/56 acc:0.75, loss:0.7951289543416351
# batch 25/56 acc:0.8125, loss:0.48210733593441546
# batch 26/56 acc:0.65625, loss:0.6463188614579849
# batch 27/56 acc:0.625, loss:0.8190727889304981
# batch 28/56 acc:0.5625, loss:0.8155993194086477
# batch 29/56 acc:0.75, loss:0.7638408616185188
# batch 30/56 acc:0.6875, loss:0.9502798052853905
# batch 31/56 acc:0.65625, loss:0.7947986795334145
# batch 32/56 acc:0.5, loss:1.032794256345369
# batch 33/56 acc:0.6875, loss:0.6475399197661318
# batch 34/56 acc:0.59375, loss:1.023997260024771
# batch 35/56 acc:0.65625, loss:0.9038949855603278
# batch 36/56 acc:0.625, loss:1.0254639423219487
# batch 37/56 acc:0.6875, loss:0.7860978544922546
# batch 38/56 acc:0.71875, loss:0.7894313471624628
# batch 39/56 acc:0.84375, loss:0.6306856408482417
# batch 40/56 acc:0.71875, loss:0.8561271145008504
# batch 41/56 acc:0.84375, loss:0.6535123178036883
# batch 42/56 acc:0.75, loss:0.7479731113417074
# batch 43/56 acc:0.71875, loss:0.8347328935051337
# batch 44/56 acc:0.78125, loss:0.6262544709024951
# batch 45/56 acc:0.8125, loss:0.5240161190740764
# batch 46/56 acc:0.6875, loss:0.8667040496366099
# batch 47/56 acc:0.78125, loss:0.5685646791826002
# batch 48/56 acc:0.71875, loss:0.711074939055834
# batch 49/56 acc:0.6875, loss:0.8422610522247851
# batch 50/56 acc:0.78125, loss:0.6848009064269718
# batch 51/56 acc:0.78125, loss:0.6291917443159036
# batch 52/56 acc:0.8125, loss:0.5774007349973544
# batch 53/56 acc:0.71875, loss:0.6242619205731899
# batch 54/56 acc:0.65625, loss:0.9442845915909857
# batch 55/56 acc:0.65625, loss:0.9523159092059359
# batch 56/56 acc:0.6551724076271057, loss:0.7926835410361146
# epoch: 17/25
# epoch 18.
# batch 0/56 acc:0.65625, loss:0.7886365510057658
# batch 1/56 acc:0.65625, loss:0.8545735490333755
# batch 2/56 acc:0.71875, loss:0.6672425126307644
# batch 3/56 acc:0.71875, loss:0.7662048935308121
# batch 4/56 acc:0.75, loss:0.7012304177042097
# batch 5/56 acc:0.75, loss:0.7837198316119611
# batch 6/56 acc:0.65625, loss:0.7220813033636659
# batch 7/56 acc:0.625, loss:1.0108559502696153
# batch 8/56 acc:0.6875, loss:0.5950627118581906
# batch 9/56 acc:0.75, loss:0.6114016136853024
# batch 10/56 acc:0.625, loss:1.1002056939760223
# batch 11/56 acc:0.78125, loss:0.8933315741160186
# batch 12/56 acc:0.6875, loss:0.7961458225618117
# batch 13/56 acc:0.59375, loss:0.9454598421434639
# batch 14/56 acc:0.6875, loss:0.799974827823462
# batch 15/56 acc:0.6875, loss:0.8462113116402179
# batch 16/56 acc:0.46875, loss:1.1181449681171216
# batch 17/56 acc:0.625, loss:0.7457379046245478
# batch 18/56 acc:0.75, loss:0.6650133951334283
# batch 19/56 acc:0.78125, loss:0.615110308281146
# batch 20/56 acc:0.78125, loss:0.588960787805263
# batch 21/56 acc:0.65625, loss:0.8333719942602329
# batch 22/56 acc:0.5625, loss:0.966532408259809
# batch 23/56 acc:0.65625, loss:0.8567202260019258
# ...
# batch 12/56 acc:0.78125, loss:0.4790898752398789
# batch 13/56 acc:0.71875, loss:0.6864185289014131
# batch 14/56 acc:0.8125, loss:0.5737301221815869
# batch 15/56 acc:0.8125, loss:0.5241832631872967
# batch 16/56 acc:0.71875, loss:0.7802003384567797
# batch 17/56 acc:0.84375, loss:0.5991090715397149
# batch 18/56 acc:0.84375, loss:0.5055919882142916
# batch 19/56 acc:0.75, loss:0.742620125063695
# batch 20/56 acc:0.8125, loss:0.5686348668532446
# batch 21/56 acc:0.65625, loss:0.8972186341416091
# batch 22/56 acc:0.71875, loss:0.7978917048312724
# batch 23/56 acc:0.78125, loss:0.6822949359775521
# batch 24/56 acc:0.6875, loss:0.8476416234043427
# batch 25/56 acc:0.8125, loss:0.6769205899036024
# batch 26/56 acc:0.6875, loss:0.8220427167252637
# batch 27/56 acc:0.71875, loss:0.8839231100282632
# batch 28/56 acc:0.75, loss:0.6841131371911615
# batch 29/56 acc:0.75, loss:0.646167692146264
# batch 30/56 acc:0.6875, loss:0.8529391979100183
# batch 31/56 acc:0.75, loss:0.7155763027840294
# batch 32/56 acc:0.75, loss:0.7280840123421513
# batch 33/56 acc:0.65625, loss:0.8150546480610501
# batch 34/56 acc:0.90625, loss:0.5550936135405209
# batch 35/56 acc:0.65625, loss:0.8650208570761606
# batch 36/56 acc:0.71875, loss:0.9233517318498343
# batch 37/56 acc:0.625, loss:0.8532564268098213
# batch 38/56 acc:0.6875, loss:0.7296271547675133
# batch 39/56 acc:0.5625, loss:0.8377071524155326
# batch 40/56 acc:0.78125, loss:0.5458874937612563
# batch 41/56 acc:0.6875, loss:0.6237479121482465
# batch 42/56 acc:0.8125, loss:0.6936672208248638
# batch 43/56 acc:0.65625, loss:0.7593974040355533
# batch 44/56 acc:0.84375, loss:0.36362210928928107
# batch 45/56 acc:0.75, loss:0.7022210087161511
# batch 46/56 acc:0.8125, loss:0.6153069524443708
# batch 47/56 acc:0.75, loss:0.6508169862208888
# batch 48/56 acc:0.71875, loss:0.7726066803443246
# batch 49/56 acc:0.65625, loss:0.8533547054685187
# batch 50/56 acc:0.75, loss:0.7643494403455406
# batch 51/56 acc:0.71875, loss:0.7220241049071774
# batch 52/56 acc:0.75, loss:0.7913002399145626
# batch 53/56 acc:0.71875, loss:0.7201271258527413
# batch 54/56 acc:0.75, loss:0.5943019154365174
# batch 55/56 acc:0.5625, loss:1.1856765570119023
# batch 56/56 acc:0.8275861740112305, loss:0.5359342559401331
# epoch: 20/25
# epoch 21.
# batch 0/56 acc:0.59375, loss:0.8506608509924263
# batch 1/56 acc:0.84375, loss:0.49202941020485014
# batch 2/56 acc:0.59375, loss:0.8965260920813307
# batch 3/56 acc:0.78125, loss:0.554439652711153
# batch 4/56 acc:0.65625, loss:0.7496723884250969
# batch 5/56 acc:0.75, loss:0.499000069568865
# batch 6/56 acc:0.75, loss:0.6172469955054112
# batch 7/56 acc:0.8125, loss:0.6275856231804937
# batch 8/56 acc:0.75, loss:0.6449787349265534
# batch 9/56 acc:0.84375, loss:0.5757193074095994
# batch 10/56 acc:0.84375, loss:0.5134117106208578
# batch 11/56 acc:0.625, loss:0.9889196571311913
# batch 12/56 acc:0.71875, loss:0.792720479570562
# batch 13/56 acc:0.78125, loss:0.6060324907302856
# batch 14/56 acc:0.84375, loss:0.5021071073715575
# batch 15/56 acc:0.75, loss:0.5603756055352278
# batch 16/56 acc:0.75, loss:0.8921378890518099
# batch 17/56 acc:0.75, loss:0.5899841946084052
# batch 18/56 acc:0.71875, loss:0.7110053326468915
# batch 19/56 acc:0.6875, loss:0.5907115029986016
# batch 20/56 acc:0.78125, loss:0.626939271343872
# batch 21/56 acc:0.71875, loss:0.86854162911186
# batch 22/56 acc:0.84375, loss:0.6440626985859126
# batch 23/56 acc:0.84375, loss:0.4825219026533887
# batch 24/56 acc:0.65625, loss:0.7928471069899388
# batch 25/56 acc:0.78125, loss:0.5708670334715862
# batch 26/56 acc:0.59375, loss:0.9581950087449513
# batch 27/56 acc:0.625, loss:0.8244999164016917
# batch 28/56 acc:0.6875, loss:0.737760940217413
# batch 29/56 acc:0.5625, loss:1.0209418689482845
# batch 30/56 acc:0.65625, loss:0.8664630074054003
# batch 31/56 acc:0.6875, loss:0.9034501687856391
# batch 32/56 acc:0.65625, loss:0.7524026893079281
# batch 33/56 acc:0.78125, loss:0.5621531088836491
# batch 34/56 acc:0.625, loss:0.843147330568172
# batch 35/56 acc:0.75, loss:0.6922224131412804
# batch 36/56 acc:0.84375, loss:0.4868721595266834
# batch 37/56 acc:0.78125, loss:0.7485486778896302
# batch 38/56 acc:0.71875, loss:0.6107031833380461
# batch 39/56 acc:0.65625, loss:1.0373744679964148
# batch 40/56 acc:0.65625, loss:0.8208804180612788
# batch 41/56 acc:0.71875, loss:0.761875472846441
# batch 42/56 acc:0.59375, loss:1.0318975256523117
# batch 43/56 acc:0.75, loss:0.7049487853655592
# batch 44/56 acc:0.75, loss:0.734647853882052
# batch 45/56 acc:0.71875, loss:0.838983069814276
# batch 46/56 acc:0.75, loss:0.8197988492902368
# batch 47/56 acc:0.8125, loss:0.6688421746948734
# batch 48/56 acc:0.75, loss:0.6801901260623708
# batch 49/56 acc:0.75, loss:0.7247355722065549
# batch 50/56 acc:0.875, loss:0.5847293477854691
# batch 51/56 acc:0.71875, loss:0.8528395468601957
# batch 52/56 acc:0.8125, loss:0.5800560803036205
# batch 53/56 acc:0.78125, loss:0.7111430789809674
# batch 54/56 acc:0.75, loss:0.7307540666952264
# batch 55/56 acc:0.84375, loss:0.5302235576964449
# batch 56/56 acc:0.7241379022598267, loss:0.7614959016891902
# epoch: 21/25
# epoch 22.
# batch 0/56 acc:0.59375, loss:0.9293232992931735
# batch 1/56 acc:0.75, loss:0.7020273721718695
# batch 2/56 acc:0.6875, loss:0.7622491599613568
# batch 3/56 acc:0.65625, loss:0.8699701367731905
# batch 4/56 acc:0.8125, loss:0.7172698196955025
# batch 5/56 acc:0.625, loss:0.8522127386822831
# batch 6/56 acc:0.875, loss:0.500264279791736
# batch 7/56 acc:0.84375, loss:0.36467490761424415
# batch 8/56 acc:0.8125, loss:0.6603645266441163
# batch 9/56 acc:0.875, loss:0.4737915543446434
# batch 10/56 acc:0.75, loss:0.5786672084068414
# batch 11/56 acc:0.75, loss:0.7010862709939829
# batch 12/56 acc:0.75, loss:0.6115517123253085
# batch 13/56 acc:0.65625, loss:0.76866567748948
# batch 14/56 acc:0.8125, loss:0.4538732841901947
# batch 15/56 acc:0.65625, loss:0.6645020203432068
# batch 16/56 acc:0.8125, loss:0.490637114882702
# batch 17/56 acc:0.78125, loss:0.7088807495601941
# batch 18/56 acc:0.71875, loss:0.7403067241684766
# batch 19/56 acc:0.71875, loss:0.684488232654985
# batch 20/56 acc:0.65625, loss:0.9485641571955057
# batch 21/56 acc:0.71875, loss:0.8551477122528013
# batch 22/56 acc:0.8125, loss:0.5796224016230553
# batch 23/56 acc:0.875, loss:0.4483335023323889
# batch 24/56 acc:0.6875, loss:0.7393911400868092
# batch 25/56 acc:0.71875, loss:0.7317691395874135
# batch 26/56 acc:0.59375, loss:1.0003270449233241
# batch 27/56 acc:0.65625, loss:0.679834061593283
# batch 28/56 acc:0.875, loss:0.5364400697872043
# batch 29/56 acc:0.78125, loss:0.503740541083971
# batch 30/56 acc:0.6875, loss:0.6232411063028849
# batch 31/56 acc:0.8125, loss:0.5171470098139253
# batch 32/56 acc:0.875, loss:0.39789705304428935
# batch 33/56 acc:0.75, loss:0.7077525595377665
# batch 34/56 acc:0.59375, loss:0.9762408566602971
# batch 35/56 acc:0.8125, loss:0.7154729340400081
# batch 36/56 acc:0.75, loss:0.8166381895134691
# batch 37/56 acc:0.59375, loss:1.0289192581549287
# batch 38/56 acc:0.625, loss:0.7346775599871762
# batch 39/56 acc:0.84375, loss:0.5238595879345667
# batch 40/56 acc:0.71875, loss:0.7695066732703708
# batch 41/56 acc:0.71875, loss:0.8913537280022865
# batch 42/56 acc:0.65625, loss:0.7403294933028519
# batch 43/56 acc:0.71875, loss:0.6861314077395946
# batch 44/56 acc:0.78125, loss:0.7137861982337199
# batch 45/56 acc:0.75, loss:0.7324714992428198
# batch 46/56 acc:0.71875, loss:0.8609841007273644
# batch 47/56 acc:0.6875, loss:0.6185020829725545
# batch 48/56 acc:0.84375, loss:0.5631189274718054
# batch 49/56 acc:0.71875, loss:0.8260917739244178
# batch 50/56 acc:0.75, loss:0.7288138836156577
# batch 51/56 acc:0.625, loss:0.9241649734321982
# batch 52/56 acc:0.59375, loss:0.9591952948831022
# batch 53/56 acc:0.75, loss:0.6434888092335314
# batch 54/56 acc:0.875, loss:0.530618141987361
# batch 55/56 acc:0.75, loss:0.7026410535909235
# batch 56/56 acc:0.7586206793785095, loss:0.6109976595074966
# epoch: 22/25
# epoch 23.
# batch 0/56 acc:0.75, loss:0.8837560703395866
# batch 1/56 acc:0.78125, loss:0.6166195111582056
# batch 2/56 acc:0.78125, loss:0.482632796629332
# batch 3/56 acc:0.78125, loss:0.649742002657149
# batch 4/56 acc:0.71875, loss:0.8656027811812237
# batch 5/56 acc:0.78125, loss:0.6337584207649343
# batch 6/56 acc:0.71875, loss:0.887442785751773
# batch 7/56 acc:0.8125, loss:0.5616494359564967
# batch 8/56 acc:0.8125, loss:0.4706613601301797
# batch 9/56 acc:0.75, loss:0.8429653904604493
# batch 10/56 acc:0.71875, loss:0.8495025681331754
# batch 11/56 acc:0.84375, loss:0.5252216088701971
# batch 12/56 acc:0.59375, loss:1.0699817258864641
# batch 13/56 acc:0.78125, loss:0.5829106800301815
# batch 14/56 acc:0.71875, loss:0.5572962647711392
# batch 15/56 acc:0.53125, loss:1.0495852630701847
# batch 16/56 acc:0.8125, loss:0.5955594472179655
# batch 17/56 acc:0.71875, loss:0.8206723644980229
# batch 18/56 acc:0.625, loss:0.6767438789029256
# batch 19/56 acc:0.8125, loss:0.4614299272361677
# batch 20/56 acc:0.625, loss:0.8872968790383311
# batch 21/56 acc:0.84375, loss:0.6067900566849858
# batch 22/56 acc:0.75, loss:0.7611940496863099
# batch 23/56 acc:0.8125, loss:0.7018964529270306
# batch 24/56 acc:0.75, loss:0.7763555725396145
# batch 25/56 acc:0.8125, loss:0.6583431936160196
# batch 26/56 acc:0.71875, loss:0.6008541284245439
# batch 27/56 acc:0.875, loss:0.4158877825830132
# batch 28/56 acc:0.75, loss:0.6850605674844701
# batch 29/56 acc:0.75, loss:0.5899805675726384
# batch 30/56 acc:0.8125, loss:0.6028252349351533
# batch 31/56 acc:0.8125, loss:0.5920916626928374
# batch 32/56 acc:0.78125, loss:0.6137475363211706
# batch 33/56 acc:0.78125, loss:0.5521187271806411
# batch 34/56 acc:0.6875, loss:0.7012621178291738
# batch 35/56 acc:0.75, loss:0.6082142852828838
# batch 36/56 acc:0.75, loss:0.7617404318589251
# batch 37/56 acc:0.8125, loss:0.5513262667518575
# batch 38/56 acc:0.75, loss:0.6533315216365736
# batch 39/56 acc:0.59375, loss:1.0641317226691172
# batch 40/56 acc:0.625, loss:0.8085838879778748
# batch 41/56 acc:0.78125, loss:0.5334243058750872
# batch 42/56 acc:0.71875, loss:0.5066890036105178
# batch 43/56 acc:0.6875, loss:0.738049184976262
# batch 44/56 acc:0.78125, loss:0.5624313540465664
# batch 45/56 acc:0.75, loss:0.8134670810541138
# batch 46/56 acc:0.6875, loss:0.7732159760635113
# batch 47/56 acc:0.8125, loss:0.6174143914831802
# batch 48/56 acc:0.78125, loss:0.6535237518837675
# batch 49/56 acc:0.75, loss:0.8006926405359991
# batch 50/56 acc:0.78125, loss:0.7387973914155737
# batch 51/56 acc:0.71875, loss:0.76995484350482
# batch 52/56 acc:0.8125, loss:0.6888584223779617
# batch 53/56 acc:0.6875, loss:0.8944615384971257
# batch 54/56 acc:0.78125, loss:0.67706948905834
# batch 55/56 acc:0.78125, loss:0.6428562097135
# batch 56/56 acc:0.7586206793785095, loss:0.5364240659079675
# epoch: 23/25
# epoch 24.
# batch 0/56 acc:0.65625, loss:0.9135388754948508
# batch 1/56 acc:0.8125, loss:0.5166949690319598
# batch 2/56 acc:0.78125, loss:0.6326780831441283
# batch 3/56 acc:0.875, loss:0.39354816440027207
# batch 4/56 acc:0.78125, loss:0.6992709011828993
# batch 5/56 acc:0.78125, loss:0.5330223379132804
# batch 6/56 acc:0.78125, loss:0.6557720699638594
# batch 7/56 acc:0.84375, loss:0.521392596536316
# batch 8/56 acc:0.8125, loss:0.5742064231308177
# batch 9/56 acc:0.75, loss:0.766397828789195
# batch 10/56 acc:0.6875, loss:0.739007759373635
# batch 11/56 acc:0.6875, loss:0.8952389598125592
# batch 12/56 acc:0.78125, loss:0.6029412872449029
# batch 13/56 acc:0.75, loss:0.633743079873966
# batch 14/56 acc:0.71875, loss:0.7383609156240709
# batch 15/56 acc:0.6875, loss:0.7995689359959215
# batch 16/56 acc:0.5, loss:1.1757345934674959
# batch 17/56 acc:0.75, loss:0.6781519378710072
# batch 18/56 acc:0.75, loss:0.8260226895654341
# batch 19/56 acc:0.75, loss:0.5257536647259258
# batch 20/56 acc:0.6875, loss:0.7969884935300797
# batch 21/56 acc:0.75, loss:0.7346362168318592
# batch 22/56 acc:0.75, loss:0.6113235094526317
# batch 23/56 acc:0.78125, loss:0.7784849133895477
# batch 24/56 acc:0.78125, loss:0.5916243341343943
# batch 25/56 acc:0.71875, loss:0.6135360709449742
# batch 26/56 acc:0.78125, loss:0.5628875791153405
# batch 27/56 acc:0.90625, loss:0.363757380284369
# batch 28/56 acc:0.8125, loss:0.4740591844310984
# batch 29/56 acc:0.6875, loss:0.7513717970432481
# batch 30/56 acc:0.71875, loss:0.7905850717215799
# batch 31/56 acc:0.8125, loss:0.5641654294886393
# batch 32/56 acc:0.8125, loss:0.6103506848448887
# batch 33/56 acc:0.71875, loss:0.6840945074509364
# batch 34/56 acc:0.75, loss:0.7244610634515993
# batch 35/56 acc:0.78125, loss:0.8045017182776064
# batch 36/56 acc:0.6875, loss:0.727678043404012
# batch 37/56 acc:0.71875, loss:0.7963147728005424
# batch 38/56 acc:0.84375, loss:0.517145145277027
# batch 39/56 acc:0.8125, loss:0.37931867002043873
# batch 40/56 acc:0.78125, loss:0.731565508118365
# batch 41/56 acc:0.6875, loss:0.7913478631526232
# batch 42/56 acc:0.78125, loss:0.5998400897951797
# batch 43/56 acc:0.75, loss:0.6678463376592845
# batch 44/56 acc:0.71875, loss:0.8087905938155018
# batch 45/56 acc:0.71875, loss:0.7740059826319339
# batch 46/56 acc:0.65625, loss:0.8294467822997831
# batch 47/56 acc:0.875, loss:0.3281196332536638
# batch 48/56 acc:0.65625, loss:0.8224428457324393
# batch 49/56 acc:0.65625, loss:0.8679500342695974
# batch 50/56 acc:0.75, loss:0.6489405992324464
# batch 51/56 acc:0.8125, loss:0.5648989806650206
# batch 52/56 acc:0.78125, loss:0.693555455742171
# batch 53/56 acc:0.5625, loss:1.2164586497819982
# batch 54/56 acc:0.625, loss:0.9732443405082449
# batch 55/56 acc:0.78125, loss:0.5034152395674028
# batch 56/56 acc:0.6551724076271057, loss:0.6702248260764212
# epoch: 24/25
# epoch 25.
# batch 0/56 acc:0.84375, loss:0.5253547381144017
# batch 1/56 acc:0.71875, loss:0.5394309283001348
# batch 2/56 acc:0.78125, loss:0.5776244364096783
# batch 3/56 acc:0.8125, loss:0.5487126733059995
# batch 4/56 acc:0.875, loss:0.5895183851243928
# batch 5/56 acc:0.75, loss:0.7621984516154043
# batch 6/56 acc:0.75, loss:0.8903265991830267
# batch 7/56 acc:0.65625, loss:1.0204755819650018
# batch 8/56 acc:0.78125, loss:0.6617020707926713
# batch 9/56 acc:0.65625, loss:0.6866394995013252
# batch 10/56 acc:0.71875, loss:0.7159353410825133
# batch 11/56 acc:0.8125, loss:0.5884514014178421
# batch 12/56 acc:0.78125, loss:0.7353788872715086
# batch 13/56 acc:0.71875, loss:0.7645413971331436
# batch 14/56 acc:0.65625, loss:0.9284708850609604
# batch 15/56 acc:0.71875, loss:0.6363002595608123
# batch 16/56 acc:0.78125, loss:0.8052735017845407
# batch 17/56 acc:0.78125, loss:0.5948700401349925
# batch 18/56 acc:0.75, loss:0.842401206959039
# batch 19/56 acc:0.78125, loss:0.580266471602954
# batch 20/56 acc:0.625, loss:0.8686489499377785
# batch 21/56 acc:0.75, loss:0.8062936536443885
# batch 22/56 acc:0.625, loss:0.7357322756797657
# batch 23/56 acc:0.75, loss:0.7232853744062595
# batch 24/56 acc:0.75, loss:0.6430346623819787
# batch 25/56 acc:0.6875, loss:0.7781227509112796
# batch 26/56 acc:0.59375, loss:0.9058231455783243
# batch 27/56 acc:0.75, loss:0.9412791691866005
# batch 28/56 acc:0.625, loss:0.7716786275850609
# batch 29/56 acc:0.65625, loss:0.8241881785797887
# batch 30/56 acc:0.78125, loss:0.6893886414836743
# batch 31/56 acc:0.78125, loss:0.6399335198511835
# batch 32/56 acc:0.75, loss:0.7671552178217098
# batch 33/56 acc:0.84375, loss:0.5784524463379057
# batch 34/56 acc:0.71875, loss:0.6149333587964065
# batch 35/56 acc:0.6875, loss:0.679863195924554
# batch 36/56 acc:0.625, loss:0.8443004526052391
# batch 37/56 acc:0.6875, loss:0.6894810015219264
# batch 38/56 acc:0.90625, loss:0.3804948137840256
# batch 39/56 acc:0.71875, loss:0.622460089129163
# batch 40/56 acc:0.84375, loss:0.4564044598955661
# batch 41/56 acc:0.8125, loss:0.5668090849067084
# batch 42/56 acc:0.78125, loss:0.6685574943549
# batch 43/56 acc:0.6875, loss:0.8507378365029581
# batch 44/56 acc:0.71875, loss:0.827744087058818
# batch 45/56 acc:0.78125, loss:0.7638601193320937
# batch 46/56 acc:0.78125, loss:0.737897197395796
# batch 47/56 acc:0.71875, loss:0.6718383942206856
# batch 48/56 acc:0.65625, loss:0.8475169390439987
# batch 49/56 acc:0.8125, loss:0.5160604151024017
# batch 50/56 acc:0.8125, loss:0.510570062790066
# batch 51/56 acc:0.75, loss:0.6454308850807138
# batch 52/56 acc:0.65625, loss:0.8754203395801596
# batch 53/56 acc:0.71875, loss:0.718073325115256
# batch 54/56 acc:0.71875, loss:0.7454208935960196
# batch 55/56 acc:0.78125, loss:0.7015272077405825
# batch 56/56 acc:0.6206896305084229, loss:0.8650054109507593
# epoch: 25/25

# %%
writer.close()

# %%
res50.eval()
# Out:
# ResNet(
#   (conv1): ConvBlock(
#     (relu): ReLU()
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (conv2_x): Sequential(
#     (0): ResBlock(
#       (relu): ReLU()
#       (convseq): Sequential(
#         (0): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (iden): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): ResBlock(
#       (relu): ReLU()
#       (convseq): Sequential(
#         (0): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (iden): Identity()
#     )
#     (2): ResBlock(
#       (relu): ReLU()
#       (convseq): Sequential(
#         (0): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (iden): Identity()
#     )
#   )
#   (conv3_x): Sequential(
#     (0): ResBlock(
#       (relu): ReLU()
#       (convseq): Sequential(
#         (0): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(2, 2))
#           (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (iden): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#     )
#     (1): ResBlock(
#       (relu): ReLU()
#       (convseq): Sequential(
#         (0): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (iden): Identity()
#     )
#     (2): ResBlock(
#       (relu): ReLU()
#       (convseq): Sequential(
#         (0): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (iden): Identity()
#     )
#     (3): ResBlock(
#       (relu): ReLU()
#       (convseq): Sequential(
#         (0): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (iden): Identity()
#     )
#   )
#   (conv4_x): Sequential(
#     (0): ResBlock(
#       (relu): ReLU()
#       (convseq): Sequential(
#         (0): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(2, 2))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (iden): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2))
#     )
#     (1): ResBlock(
#       (relu): ReLU()
#       (convseq): Sequential(
#         (0): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (iden): Identity()
#     )
#     (2): ResBlock(
#       (relu): ReLU()
#       (convseq): Sequential(
#         (0): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (iden): Identity()
#     )
#     (3): ResBlock(
#       (relu): ReLU()
#       (convseq): Sequential(
#         (0): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (iden): Identity()
#     )
#     (4): ResBlock(
#       (relu): ReLU()
#       (convseq): Sequential(
#         (0): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (iden): Identity()
#     )
#     (5): ResBlock(
#       (relu): ReLU()
#       (convseq): Sequential(
#         (0): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (iden): Identity()
#     )
#   )
#   (conv5_x): Sequential(
#     (0): ResBlock(
#       (relu): ReLU()
#       (convseq): Sequential(
#         (0): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(2, 2))
#           (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (iden): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2))
#     )
#     (1): ResBlock(
#       (relu): ReLU()
#       (convseq): Sequential(
#         (0): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (iden): Identity()
#     )
#     (2): ResBlock(
#       (relu): ReLU()
#       (convseq): Sequential(
#         (0): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): ConvBlock(
#           (relu): ReLU()
#           (conv): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#           (batchnorm): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (iden): Identity()
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (fc): Linear(in_features=2048, out_features=4, bias=True)
#   (gapool): AdaptiveAvgPool2d(output_size=(1, 1))
# )

# %%
# validate accuracy
# run["valid/acc"] = correct / len(trainloader.dataset)

# %% [markdown]
# ### Save Model state
# - https://freshrimpsushi.github.io/posts/saving-and-loading-a-general-checkpoint-in-pytorch/

# %%
import torchvision.models as models

# %%
torch.save(res50.state_dict(), 'model_weight_230511_centercrop.pt')

# %%
# res50.load_state_dict(torch.load('model_weight.pt'))

# %% [markdown]
# ### Submission

# %%
submission_csv = op(path, "sample_submission.csv")

# %%
pred_list = []

# %%
for i in range(len(test_data.img_labels)):
    img_title = test_data.img_labels.iloc[i, 0]
    img_dir = img_title + '.jpg'
    print(op(test_path, img_dir))
    
    # img = read_image_resize(op(test_path, img_dir))
    img = centercrop(op(test_path, img_dir))
    
    img = img.reshape(1, 3, 224, 224)
    inputs = img.to(device)
    outputs = res50(inputs)
    _, preds = torch.max(outputs, 1)
    ans = [img_title, 0, 0, 0, 0]
    ans[int(preds) + 1] = 1
    pred_list.append(ans)
# Out:
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_0.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_2.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_3.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_4.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_5.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_6.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_7.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_8.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_9.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_10.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_11.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_12.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_13.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_14.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_15.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_16.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_17.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_18.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_19.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_20.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_21.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_22.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_23.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_24.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_25.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_26.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_27.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_28.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_29.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_30.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_31.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_32.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_33.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_34.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_35.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_36.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_37.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_38.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_39.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_40.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_41.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_42.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_43.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_44.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_45.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_46.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_47.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_48.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_49.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_50.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_51.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_52.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_53.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_54.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_55.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_56.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_57.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_58.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_59.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_60.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_61.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_62.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_63.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_64.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_65.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_66.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_67.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_68.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_69.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_70.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_71.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_72.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_73.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_74.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_75.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_76.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_77.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_78.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_79.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_80.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_81.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_82.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_83.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_84.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_85.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_86.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_87.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_88.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_89.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_90.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_91.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_92.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_93.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_94.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_95.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_96.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_97.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_98.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_99.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_100.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_101.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_102.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_103.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_104.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_105.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_106.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_107.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_108.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_109.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_110.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_111.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_112.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_113.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_114.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_115.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_116.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_117.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_118.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_119.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_120.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_121.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_122.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_123.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_124.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_125.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_126.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_127.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_128.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_129.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_130.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_131.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_132.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_133.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_134.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_135.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_136.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_137.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_138.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_139.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_140.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_141.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_142.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_143.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_144.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_145.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_146.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_147.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_148.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_149.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_150.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_151.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_152.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_153.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_154.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_155.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_156.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_157.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_158.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_159.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_160.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_161.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_162.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_163.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_164.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_165.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_166.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_167.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_168.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_169.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_170.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_171.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_172.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_173.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_174.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_175.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_176.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_177.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_178.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_179.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_180.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_181.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_182.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_183.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_184.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_185.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_186.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_187.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_188.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_189.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_190.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_191.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_192.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_193.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_194.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_195.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_196.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_197.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_198.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_199.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_200.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_201.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_202.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_203.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_204.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_205.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_206.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_207.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_208.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_209.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_210.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_211.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_212.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_213.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_214.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_215.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_216.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_217.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_218.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_219.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_220.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_221.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_222.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_223.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_224.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_225.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_226.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_227.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_228.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_229.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_230.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_231.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_232.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_233.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_234.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_235.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_236.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_237.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_238.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_239.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_240.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_241.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_242.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_243.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_244.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_245.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_246.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_247.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_248.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_249.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_250.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_251.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_252.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_253.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_254.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_255.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_256.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_257.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_258.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_259.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_260.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_261.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_262.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_263.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_264.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_265.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_266.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_267.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_268.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_269.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_270.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_271.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_272.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_273.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_274.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_275.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_276.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_277.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_278.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_279.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_280.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_281.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_282.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_283.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_284.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_285.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_286.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_287.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_288.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_289.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_290.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_291.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_292.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_293.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_294.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_295.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_296.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_297.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_298.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_299.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_300.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_301.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_302.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_303.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_304.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_305.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_306.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_307.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_308.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_309.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_310.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_311.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_312.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_313.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_314.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_315.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_316.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_317.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_318.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_319.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_320.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_321.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_322.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_323.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_324.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_325.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_326.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_327.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_328.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_329.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_330.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_331.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_332.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_333.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_334.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_335.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_336.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_337.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_338.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_339.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_340.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_341.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_342.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_343.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_344.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_345.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_346.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_347.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_348.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_349.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_350.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_351.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_352.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_353.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_354.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_355.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_356.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_357.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_358.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_359.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_360.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_361.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_362.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_363.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_364.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_365.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_366.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_367.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_368.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_369.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_370.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_371.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_372.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_373.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_374.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_375.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_376.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_377.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_378.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_379.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_380.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_381.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_382.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_383.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_384.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_385.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_386.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_387.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_388.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_389.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_390.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_391.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_392.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_393.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_394.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_395.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_396.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_397.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_398.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_399.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_400.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_401.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_402.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_403.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_404.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_405.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_406.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_407.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_408.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_409.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_410.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_411.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_412.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_413.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_414.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_415.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_416.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_417.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_418.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_419.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_420.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_421.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_422.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_423.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_424.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_425.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_426.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_427.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_428.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_429.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_430.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_431.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_432.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_433.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_434.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_435.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_436.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_437.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_438.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_439.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_440.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_441.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_442.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_443.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_444.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_445.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_446.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_447.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_448.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_449.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_450.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_451.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_452.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_453.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_454.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_455.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_456.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_457.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_458.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_459.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_460.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_461.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_462.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_463.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_464.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_465.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_466.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_467.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_468.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_469.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_470.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_471.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_472.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_473.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_474.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_475.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_476.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_477.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_478.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_479.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_480.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_481.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_482.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_483.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_484.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_485.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_486.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_487.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_488.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_489.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_490.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_491.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_492.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_493.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_494.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_495.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_496.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_497.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_498.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_499.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_500.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_501.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_502.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_503.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_504.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_505.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_506.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_507.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_508.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_509.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_510.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_511.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_512.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_513.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_514.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_515.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_516.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_517.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_518.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_519.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_520.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_521.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_522.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_523.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_524.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_525.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_526.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_527.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_528.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_529.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_530.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_531.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_532.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_533.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_534.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_535.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_536.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_537.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_538.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_539.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_540.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_541.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_542.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_543.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_544.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_545.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_546.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_547.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_548.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_549.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_550.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_551.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_552.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_553.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_554.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_555.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_556.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_557.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_558.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_559.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_560.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_561.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_562.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_563.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_564.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_565.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_566.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_567.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_568.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_569.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_570.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_571.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_572.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_573.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_574.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_575.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_576.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_577.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_578.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_579.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_580.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_581.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_582.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_583.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_584.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_585.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_586.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_587.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_588.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_589.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_590.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_591.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_592.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_593.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_594.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_595.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_596.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_597.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_598.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_599.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_600.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_601.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_602.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_603.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_604.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_605.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_606.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_607.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_608.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_609.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_610.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_611.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_612.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_613.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_614.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_615.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_616.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_617.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_618.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_619.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_620.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_621.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_622.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_623.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_624.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_625.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_626.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_627.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_628.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_629.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_630.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_631.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_632.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_633.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_634.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_635.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_636.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_637.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_638.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_639.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_640.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_641.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_642.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_643.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_644.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_645.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_646.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_647.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_648.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_649.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_650.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_651.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_652.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_653.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_654.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_655.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_656.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_657.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_658.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_659.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_660.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_661.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_662.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_663.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_664.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_665.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_666.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_667.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_668.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_669.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_670.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_671.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_672.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_673.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_674.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_675.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_676.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_677.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_678.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_679.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_680.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_681.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_682.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_683.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_684.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_685.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_686.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_687.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_688.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_689.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_690.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_691.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_692.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_693.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_694.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_695.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_696.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_697.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_698.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_699.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_700.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_701.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_702.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_703.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_704.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_705.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_706.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_707.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_708.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_709.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_710.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_711.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_712.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_713.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_714.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_715.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_716.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_717.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_718.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_719.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_720.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_721.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_722.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_723.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_724.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_725.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_726.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_727.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_728.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_729.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_730.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_731.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_732.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_733.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_734.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_735.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_736.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_737.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_738.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_739.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_740.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_741.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_742.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_743.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_744.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_745.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_746.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_747.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_748.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_749.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_750.jpg
# ...
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1575.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1576.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1577.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1578.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1579.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1580.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1581.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1582.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1583.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1584.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1585.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1586.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1587.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1588.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1589.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1590.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1591.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1592.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1593.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1594.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1595.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1596.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1597.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1598.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1599.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1600.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1601.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1602.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1603.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1604.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1605.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1606.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1607.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1608.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1609.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1610.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1611.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1612.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1613.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1614.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1615.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1616.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1617.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1618.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1619.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1620.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1621.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1622.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1623.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1624.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1625.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1626.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1627.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1628.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1629.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1630.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1631.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1632.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1633.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1634.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1635.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1636.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1637.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1638.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1639.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1640.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1641.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1642.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1643.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1644.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1645.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1646.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1647.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1648.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1649.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1650.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1651.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1652.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1653.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1654.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1655.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1656.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1657.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1658.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1659.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1660.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1661.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1662.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1663.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1664.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1665.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1666.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1667.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1668.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1669.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1670.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1671.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1672.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1673.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1674.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1675.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1676.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1677.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1678.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1679.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1680.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1681.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1682.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1683.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1684.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1685.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1686.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1687.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1688.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1689.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1690.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1691.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1692.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1693.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1694.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1695.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1696.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1697.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1698.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1699.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1700.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1701.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1702.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1703.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1704.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1705.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1706.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1707.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1708.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1709.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1710.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1711.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1712.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1713.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1714.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1715.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1716.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1717.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1718.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1719.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1720.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1721.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1722.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1723.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1724.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1725.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1726.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1727.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1728.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1729.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1730.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1731.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1732.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1733.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1734.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1735.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1736.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1737.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1738.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1739.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1740.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1741.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1742.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1743.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1744.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1745.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1746.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1747.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1748.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1749.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1750.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1751.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1752.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1753.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1754.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1755.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1756.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1757.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1758.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1759.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1760.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1761.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1762.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1763.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1764.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1765.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1766.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1767.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1768.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1769.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1770.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1771.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1772.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1773.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1774.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1775.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1776.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1777.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1778.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1779.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1780.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1781.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1782.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1783.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1784.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1785.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1786.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1787.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1788.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1789.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1790.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1791.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1792.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1793.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1794.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1795.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1796.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1797.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1798.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1799.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1800.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1801.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1802.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1803.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1804.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1805.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1806.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1807.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1808.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1809.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1810.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1811.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1812.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1813.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1814.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1815.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1816.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1817.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1818.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1819.jpg
# /home/dmsai2/Desktop/AI_Hackathon/data/images/Test/Test_1820.jpg

# %%
print(len(pred_list))
# Out:
# 1821

# %%
header = ['image_id', 'healthy', 'multiple_diseases', 'rust', 'scab']
pred_list.insert(0, header)
print(len(pred_list))
print(pred_list[0:5])
# Out:
# 1822
# [['image_id', 'healthy', 'multiple_diseases', 'rust', 'scab'], ['Test_0', 0, 0, 1, 0], ['Test_1', 0, 0, 1, 0], ['Test_2', 0, 0, 0, 1], ['Test_3', 1, 0, 0, 0]]

# %%
submission = pd.DataFrame(pred_list)

# %%
submission.head()
# Out:
#           0        1                  2     3     4
# 0  image_id  healthy  multiple_diseases  rust  scab
# 1    Test_0        0                  0     1     0
# 2    Test_1        0                  0     1     0
# 3    Test_2        0                  0     0     1
# 4    Test_3        1                  0     0     0

# %%
new_header = submission.iloc[0]
submission = submission[1:]
submission.columnsmns = new_header
submission.head()
# Out:
# /tmp/ipykernel_441958/1561510870.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   submission.columnsmns = new_header
#         0  1  2  3  4
# 1  Test_0  0  0  1  0
# 2  Test_1  0  0  1  0
# 3  Test_2  0  0  0  1
# 4  Test_3  1  0  0  0
# 5  Test_4  0  0  1  0

# %%
submission.to_csv("submission_cc.csv", index=False)
